# %% [markdown]
# <pre style="float: right">version 1.0.1</pre>
# # FNLP 2019: Lab Session 5: Word Sense Disambiguation
#
# ## Task Description
#
# In this tutorial, we will be exploring the word sense disambiguation task. This is a task where you use a corpus to learn how to disambiguate a small set of target words using supervised learning. The aim of this task is to build a classifier that maps each occurrence of a target word in a corpus to its sense.
#
# We will use a Naive Bayes classifier. In other words, where the context of an occurrence of a target word in the corpus is represented as a feature vector $(\vec{f})$, the classifier estimates the word sense $s\in S$ based on its context as shown below.
#
# $$
# \begin{align}
#     \hat{s} &= \arg\max_{s\in S}P(s|\vec{f}) & \text{(optimization problem)}\\
#             &= \arg\max_{s\in S}\frac{P(\vec{f}|s)P(s)}{P(\vec{f})} & \text{(Bayes rule)}\\
#             &\propto \arg\max_{s\in S}P(\vec{f}|s)P(s)  & \text{(denominator is constant)}\\
#             &\approx \arg\max_{s\in S}P(s)\prod_{i=1}^{n}P(f_i|s) & \text{(conditional independence of features)}\\
# \end{align}
# $$
#
# ## The corpus
#
# We will use the [senseval-2](http://www.hipposmond.com/senseval2) corpus for our training and test data. This corpus consists of text from a mixture of places, including the British National Corpus and the Penn Treebank portion of the Wall Street Journal. Each word in the corpus is tagged with its part of speech, and the senses of the following target words are also manually annotated: the nouns *interest*, *line*; the verb *serve* and the adjective *hard*. You can find out more about the task from [here](http://www.hipposmond.com/senseval2/descriptions/english-lexsample.htm).
#
# The sets of senses that are used to annotate each target word come from WordNet (more on that later).
#
# ## Support Code
#
# To do the analysis we use a set of helper function from ``WSD.py`` that came together with this notebook. Open this file in Jupyter build-in editor or your favourite IDE and try to understand how it works (don't worry if you don't understand some of it, it's not necessary for doing this task). We will import these functions and will use them for the rest of the lab.
# Remember, `help(...)` is your friend:
# - `help([class name])` for classes and all their methods and instance variables
# - `help([any object])` likewise
# - `help([function])` or `help([class].[method])` for functions / methods
#
# This code allows you to do several things. You can now run, train and evaluate a range of Naive Bayes classifiers over the corpus to acquire a model of WSD for a given target word: the adjective *hard*, the nouns *interest* or *line*, and the verb *serve*. We'll learn later how you do this. First, we're going to explore the nature of the corpus itself.

# %%
import nltk
from nltk.classify import NaiveBayesClassifier
from WSD import *
from pprint import pprint # Pretty-printing utilities
nltk.download('senseval')
# Out:
# [nltk_data] Downloading package senseval to
# [nltk_data]     /Users/athiyadeviyani/nltk_data...
# [nltk_data]   Unzipping corpora/senseval.zip.
# True

# %% [markdown]
# ## Data Exploration
#
# ### Target words
#
# You can find out the set of target words for the senseval-2 corpus by running:

# %%
senseval.fileids()
# Out:
# ['hard.pos', 'interest.pos', 'line.pos', 'serve.pos']

# %% [markdown]
# The result doesn't tell you the syntactic category of the words, but see the description of the corpus above

# %% [markdown]
# ### Word senses
#
# Let's now find out the set of word senses for each target word in senseval. There is a function in above that returns this information. For example:

# %%
print(instance2senses('hard.pos'))
# Out:
# ['HARD3', 'HARD1', 'HARD2']

# %% [markdown]
# As you can see this gives you `['HARD1', 'HARD2', 'HARD3']`
#
# So there are 3 senses for the adjective hard in the corpus. You'll shortly be looking at the data to guess what these 3 senses are.
#
# #### Now it's your turn:
#
# * What are the senses for the other target words? Find out by calling senses with appropriate arguments.
# * How many senses does each target have?
# * Let's now guess the sense definitions for HARD1, HARD2 and HARD3 by looking at the 100 most frequent open class words that occur in the context of each sense.

# %% [markdown]
# You can find out what these 100 words for HARD1 by running the following:

# %%
instancesHARD1 = sense2instances(senseval.instances('hard.pos'), 'HARD1')
featuresHARD1 = extract_vocab_frequency(instancesHARD1, n=100)
pprint(featuresHARD1)
# Out:
# [('harder', 475),
#  ('time', 316),
#  ('get', 224),
#  ('would', 224),
#  ('find', 206),
#  ('make', 195),
#  ('very', 187),
#  ('out', 175),
#  ('people', 165),
#  ('believe', 154),
#  ('even', 152),
#  ('hardest', 139),
#  ('going', 136),
#  ('much', 130),
#  ('like', 127),
#  ('just', 121),
#  ('now', 111),
#  ('way', 107),
#  ('imagine', 105),
#  ('see', 104),
#  ('may', 103),
#  ('other', 103),
#  ('know', 103),
#  ('could', 96),
#  ('into', 93),
#  ('many', 92),
#  ('new', 91),
#  ('tell', 88),
#  ('these', 85),
#  ('come', 85),
#  ('too', 83),
#  ('without', 82),
#  ('good', 81),
#  ('part', 79),
#  ('take', 78),
#  ('think', 77),
#  ('work', 76),
#  ('thing', 75),
#  ('really', 74),
#  ('two', 73),
#  ('go', 73),
#  ('those', 71),
#  ('makes', 70),
#  ('back', 70),
#  ('things', 70),
#  ('still', 69),
#  ('made', 67),
#  ('last', 67),
#  ('having', 66),
#  ('first', 66),
#  ('our', 64),
#  ('most', 64),
#  ('here', 63),
#  ('life', 62),
#  ('enough', 62),
#  ('keep', 62),
#  ('making', 61),
#  ('lot', 60),
#  ('year', 58),
#  ('over', 58),
#  ('long', 58),
#  ('getting', 57),
#  ('only', 55),
#  ('san', 55),
#  ('off', 55),
#  ('day', 52),
#  ('understand', 52),
#  ('home', 52),
#  ('through', 51),
#  ('might', 51),
#  ('why', 51),
#  ('sometimes', 50),
#  ('times', 50),
#  ('something', 49),
#  ('little', 49),
#  ('since', 48),
#  ('game', 48),
#  ('does', 48),
#  ('kind', 47),
#  ('put', 46),
#  ('while', 46),
#  ('job', 45),
#  ('down', 45),
#  ('children', 45),
#  ('before', 45),
#  ('become', 43),
#  ('especially', 43),
#  ('often', 43),
#  ('want', 43),
#  ('right', 42),
#  ('place', 42),
#  ('found', 41),
#  ('around', 41),
#  ('once', 41),
#  ('ever', 40),
#  ('doing', 40),
#  ('women', 40),
#  ('anything', 40),
#  ('someone', 39),
#  ('same', 39),
#  ('although', 39)]

# %% [markdown]
# #### Now it's your turn:
#
# * Call the above functions for HARD2 and HARD3.
# * Look at the resulting lists of 100 most frequent words for each sense, and try to define what HARD1, HARD2 and HARD3 mean.
# * These senses are actually the first three senses for the adjective _hard_ in [WordNet](http://wordnet.princeton.edu/). You can enter a word and get its list of WordNet senses from [here](http://wordnetweb.princeton.edu/perl/webwn). Do this for hard, and check whether your estimated definitions for the 3 word senses are correct.

# %%
# Analysis of HARD2
instancesHARD2 = sense2instances(senseval.instances('hard.pos'), 'HARD2')
featuresHARD2 = extract_vocab_frequency(instancesHARD2, n=20)
pprint(featuresHARD2)
# Analysis of HARD3
instancesHARD3 = sense2instances(senseval.instances('hard.pos'), 'HARD3')
featuresHARD3 = extract_vocab_frequency(instancesHARD3, n=20)
pprint(featuresHARD3)
# Out:
# [('work', 163),
#  ('look', 85),
#  ('take', 55),
#  ('feelings', 32),
#  ('long', 27),
#  ('people', 23),
#  ('our', 23),
#  ('time', 22),
#  ('good', 20),
#  ('way', 19),
#  ('should', 19),
#  ('harder', 18),
#  ('very', 18),
#  ('just', 18),
#  ('would', 18),
#  ('other', 18),
#  ('get', 18),
#  ('taking', 18),
#  ('line', 17),
#  ('through', 16),
#  ('now', 15)]
# [('rock', 33),
#  ('surface', 24),
#  ('between', 24),
#  ('place', 24),
#  ('soft', 21),
#  ('other', 17),
#  ('out', 17),
#  ('cover', 17),
#  ('like', 16),
#  ('into', 16),
#  ('made', 15),
#  ('red', 13),
#  ('plastic', 13),
#  ('water', 12),
#  ('harder', 12),
#  ('good', 12),
#  ('time', 12),
#  ('first', 12),
#  ('too', 11),
#  ('may', 11),
#  ('put', 11)]

# %% [markdown]
# ## Data structure of Senseval instances
# Having extracted all instances of a given sense, you can look at what the data structures in the corpus look like:

# %%
print("For HARD2:\n Sample instance: {}\n All features:".format(instancesHARD2[0]))
pprint(instancesHARD2)
print("For HARD3:\n Sample instance: {} \n All features:".format(instancesHARD3[0]))
pprint(instancesHARD3)
# Out:
# For HARD2:
#  Sample instance: SensevalInstance(word='hard-a', position=15, context=[('keep', 'VB'), ('this', 'DT'), ('one', 'CD'), ('in', 'IN'), ('your', 'PRP$'), ('drawer', 'NN'), ('for', 'IN'), ('the', 'DT'), ('next', 'JJ'), ('time', 'NN'), ('the', 'DT'), ('boss', 'NN'), ('gives', 'VBZ'), ('you', 'PRP'), ('a', 'DT'), ('hard', 'JJ'), ('time', 'NN'), ('.', '.')], senses=('HARD2',))
#  All features:
# [SensevalInstance(word='hard-a', position=15, context=[('keep', 'VB'), ('this', 'DT'), ('one', 'CD'), ('in', 'IN'), ('your', 'PRP$'), ('drawer', 'NN'), ('for', 'IN'), ('the', 'DT'), ('next', 'JJ'), ('time', 'NN'), ('the', 'DT'), ('boss', 'NN'), ('gives', 'VBZ'), ('you', 'PRP'), ('a', 'DT'), ('hard', 'JJ'), ('time', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=11, context=[('she', 'PRP'), ('recommends', 'VBZ'), ('continuing', 'VBG'), ('education', 'NN'), ('courses', 'NNS'), (',', ','), ('developing', 'VBG'), ('effective', 'JJ'), ('people', 'NNS'), ('skills', 'NNS'), ('and', 'CC'), ('hard', 'JJ'), ('work', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=10, context=[('the', 'DT'), ('phrase', 'NN'), ('``', '``'), ('consent', 'NN'), ('of', 'IN'), ('the', 'DT'), ('governed', 'VBN'), ("''", "''"), ('needs', 'VBZ'), ('a', 'DT'), ('hard', 'JJ'), ('look', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=9, context=[('he', 'PRP'), ("'s", 'VBZ'), ('a', 'DT'), ('good', 'JJ'), ('friend', 'NN'), (',', ','), ('and', 'CC'), ('hopefully', 'RB'), ('the', 'DT'), ('hard', 'JJ'), ('work', 'NN'), ('he', 'PRP'), ('has', 'VBZ'), ('done', 'VBN'), ('on', 'IN'), ('his', 'PRP$'), ('swing', 'NN'), ('is', 'VBZ'), ('going', 'VBG'), ('to', 'TO'), ('pay', 'VB'), ('dividends', 'NNS'), ('for', 'IN'), ('him', 'PRP'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=39, context=[('``', '``'), ('what', 'WP'), ('we', 'PRP'), ('do', 'VBP'), ('is', 'VBZ'), ('really', 'RB'), ('show', 'VBP'), ('the', 'DT'), ('slapstick', 'NN'), ('side', 'NN'), ('that', 'WDT'), ('still', 'RB'), ('works', 'VBZ'), ('with', 'IN'), ('the', 'DT'), ('interpretation', 'NN'), ('(', '('), ('of', 'IN'), ('the', 'DT'), ('play', 'NN'), (')', 'SYM'), (',', ','), ('so', 'RB'), ('kids', 'NNS'), ('see', 'VBP'), ('how', 'WRB'), ('much', 'JJ'), ('fun', 'NN'), ('shakespeare', 'NNP'), ('is', 'VBZ'), ('--', ':'), ('because', 'IN'), ('he', 'PRP'), ("'s", 'VBZ'), ('(', '('), ('often', 'RB'), (')', 'SYM'), ('associated', 'VBN'), ('with', 'IN'), ('hard', 'JJ'), ('academic', 'JJ'), ('disciplines', 'NNS'), (',', ','), ('"', '"'), ('orlando', 'NNP'), ('said', 'VBD'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=16, context=[('as', 'IN'), ('an', 'DT'), ('antidote', 'NN'), ('to', 'TO'), ('the', 'DT'), ('dependency', 'NN'), ('of', 'IN'), ('this', 'DT'), ('identity', 'NN'), ('he', 'PRP'), ('routinely', 'RB'), ('advocates', 'VBZ'), ('the', 'DT'), ('classic', 'JJ'), ('values', 'NNS'), ('of', 'IN'), ('hard', 'JJ'), ('work', 'NN'), (',', ','), ('individual', 'JJ'), ('initiative', 'NN'), ('and', 'CC'), ('self-reliance', 'NN'), ('--', ':'), ('even', 'RB'), ('as', 'IN'), ('bigotry', 'NN'), ('is', 'VBZ'), ('continually', 'RB'), ('resisted', 'VBN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=17, context=[('(', '('), ('box', 'NN'), (')', 'SYM'), ('comment', 'NNP'), (':', ':'), ('``', '``'), ('(', '('), ('the', 'DT'), ('game-winning', 'JJ'), ('single', 'JJ'), (')', 'SYM'), ('is', 'VBZ'), ('a', 'DT'), ('compliment', 'NN'), ('to', 'TO'), ('all', 'PDT'), ('the', 'DT'), ('hard', 'JJ'), ('work', 'NN'), (',', ','), ('"', '"'), ('moreau', 'NNP'), ('coach', 'NNP'), ('mike', 'NNP'), ('bungarz', 'NNP'), ('said', 'VBD'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=5, context=[('it', 'PRP'), ('is', 'VBZ'), ('therefore', 'RB'), ('on', 'IN'), ('real', 'JJ'), ('hard', 'JJ'), ('cash', 'NN'), ('that', 'IN'), ('he', 'PRP'), ('bases', 'VBZ'), ('his', 'PRP$'), ('argument', 'NN'), ('that', 'IN'), ('if', 'IN'), ('manchester', 'NNP'), ('is', 'VBZ'), ('ready', 'JJ'), ('to', 'TO'), ('pay', 'VB'), ('the', 'DT'), ('top', 'JJ'), ('price', 'NN'), ('of', 'IN'), (',', ','), ('say', 'VBP'), (',', ','), ('25', 'CD'), ('s', 'PRP'), ('a', 'DT'), ('seat', 'NN'), (',', ','), ('and', 'CC'), ('fill', 'VB'), ('the', 'DT'), ('theatre', 'NN'), (',', ','), ('manchester', 'NNP'), ('can', 'MD'), ('expect', 'VB'), ('more', 'JJR'), ('of', 'IN'), ('the', 'DT'), ('world-famous', 'JJ'), ('ones', 'NNS'), ('-', ':'), ('always', 'RB'), ('provided', 'VBN'), ('that', 'IN'), ('her', 'PRP$'), ('claims', 'NNS'), ('do', 'VBP'), ('not', 'RB'), ('unhappily', 'RB'), ('conflict', 'VB'), ('with', 'IN'), ('those', 'DT'), ('of', 'IN'), ('la', 'NNP'), ('scala', 'NNP'), (',', ','), ('new', 'NNP'), ('york', 'NNP'), ("'s", 'POS'), ('metropolitan', 'JJ'), ('opera', 'NN'), (',', ','), ('vienna', 'NNP'), (',', ','), ('venice', 'NNP'), (',', ','), ('paris', 'NNP'), (',', ','), ('san', 'NNP'), ('francisco', 'NNP'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('rest', 'NN'), ('of', 'IN'), ('the', 'DT'), ('world', 'NN'), ("'s", 'POS'), ('leading', 'VBG'), ('opera', 'NN'), ('houses', 'NNS'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=1, context=[('but', 'CC'), ('hard', 'JJ'), ('lines', 'NNS'), ('are', 'VBP'), ('n', 'NN'), ("'t", 'NNP'), ('hook', 'NNP'), ("'s", 'POS'), ('style', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=13, context=[('it', 'PRP'), ('took', 'VBD'), ('hoffmann', 'NNP'), ('and', 'CC'), ('another', 'DT'), ('teacher', 'NN'), ('a', 'DT'), ('year', 'NN'), ('to', 'TO'), ('persuade', 'VB'), ('him', 'PRP'), ('to', 'TO'), ('take', 'VB'), ('harder', 'JJ'), ('classes', 'NNS'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=6, context=[('i', 'PRP'), ('have', 'VBP'), ('taken', 'VBN'), ('a', 'DT'), ('long', 'JJ'), (',', ','), ('hard', 'JJ'), ('look', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=34, context=[('a', 'DT'), ('minority', 'NN'), ('of', 'IN'), ('dissenters', 'NNS'), ('says', 'VBZ'), ('that', 'IN'), ('while', 'IN'), ('wild', 'JJ'), ('habitats', 'NNS'), ('indeed', 'RB'), ('are', 'VBP'), ('disappearing', 'VBG'), ('--', ':'), ('and', 'CC'), ('species', 'NN'), ('with', 'IN'), ('them', 'PRP'), ('--', ':'), ('because', 'IN'), ('of', 'IN'), ('human', 'JJ'), ('expansion', 'NN'), (',', ','), ('the', 'DT'), ('supposed', 'VBN'), ('magnitude', 'NN'), ('and', 'CC'), ('rate', 'NN'), ('of', 'IN'), ('the', 'DT'), ('extinctions', 'NNS'), ('are', 'VBP'), ('unsubstantiated', 'JJ'), ('by', 'IN'), ('hard', 'JJ'), ('evidence', 'NN'), ('and', 'CC'), ('probably', 'RB'), ('have', 'VBP'), ('been', 'VBN'), ('exaggerated', 'VBN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=6, context=[('``', '``'), ('that', 'DT'), ("'s", 'VBZ'), ('a', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('hard', 'JJ'), ('earned', 'VBD'), ('money', 'NN'), ('to', 'TO'), ('lose', 'VB'), ("''", "''"), (',', ','), ('he', 'PRP'), ('says', 'VBZ'), ('today', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=32, context=[('and', 'CC'), ('like', 'IN'), ('this', 'DT'), ('english', 'NNP'), ('master', 'NN'), (',', ','), ('mason', 'NNP'), ('realizes', 'VBZ'), ('his', 'PRP$'), ('subjects', 'NNS'), ('in', 'IN'), ('large', 'JJ'), (',', ','), ('simplified', 'JJ'), ('masses', 'NNS'), ('which', 'WDT'), (',', ','), ('though', 'IN'), ('they', 'PRP'), ('seem', 'VBP'), ('effortless', 'JJ'), (',', ','), ('are', 'VBP'), ('in', 'IN'), ('reality', 'NN'), ('the', 'DT'), ('result', 'NN'), ('of', 'IN'), ('skilled', 'JJ'), ('design', 'NN'), ('born', 'VBN'), ('of', 'IN'), ('hard', 'JJ'), ('work', 'NN'), ('and', 'CC'), ('a', 'DT'), ('thorough', 'JJ'), ('distillation', 'NN'), ('of', 'IN'), ('the', 'DT'), ('natural', 'JJ'), ('form', 'NN'), ('that', 'WDT'), ('inspired', 'VBD'), ('them', 'PRP'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=6, context=[('that', 'DT'), ('has', 'VBZ'), ('left', 'VBN'), ('their', 'PRP$'), ('faces', 'NNS'), ('as', 'RB'), ('hard', 'JJ'), ('as', 'IN'), ('the', 'DT'), ('lives', 'NNS'), ('they', 'PRP'), ('come', 'VBP'), ('from', 'IN'), ('and', 'CC'), ('their', 'PRP$'), ('passions', 'NNS'), ('as', 'RB'), ('heated', 'VBN'), ('as', 'IN'), ('the', 'DT'), ('desert', 'NN'), ('air', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=27, context=[('we', 'PRP'), ('move', 'VBP'), ('toward', 'IN'), ('the', 'DT'), ('next', 'JJ'), ('century', 'NN'), ('more', 'RBR'), ('confident', 'JJ'), ('than', 'IN'), ('ever', 'RB'), ('that', 'IN'), ('we', 'PRP'), ('have', 'VBP'), ('the', 'DT'), ('will', 'MD'), ('at', 'IN'), ('home', 'NN'), ('and', 'CC'), ('abroad', 'RB'), ('to', 'TO'), ('do', 'VB'), ('what', 'WP'), ('must', 'MD'), ('be', 'VB'), ('done', 'VBN'), ('--', ':'), ('the', 'DT'), ('hard', 'JJ'), ('work', 'NN'), ('of', 'IN'), ('freedom', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=8, context=[('there', 'EX'), ('is', 'VBZ'), ('no', 'DT'), ('question', 'NN'), ('he', 'PRP'), ('came', 'VBD'), ('up', 'IN'), ('the', 'DT'), ('hard', 'JJ'), ('way', 'NN'), (',', ','), ('but', 'CC'), ('there', 'EX'), ('has', 'VBZ'), ('been', 'VBN'), ('some', 'DT'), ('question', 'NN'), ('about', 'IN'), ('the', 'DT'), ('accuracy', 'NN'), ('of', 'IN'), ('his', 'PRP$'), ('version', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=40, context=[('you', 'PRP'), ('have', 'VBP'), ('probably', 'RB'), ('noticed', 'VBN'), ('that', 'IN'), ('virtually', 'RB'), ('all', 'DT'), ('cities', 'NNS'), (',', ','), ('including', 'VBG'), ('some', 'DT'), ('real', 'JJ'), ('armpits', 'NNS'), (',', ','), ('like', 'VB'), ('to', 'TO'), ('boast', 'VB'), ('that', 'IN'), ('they', 'PRP'), ('have', 'VBP'), ('museums', 'NNS'), ('and', 'CC'), ('symphonies', 'NNS'), (',', ','), ('which', 'WDT'), ('are', 'VBP'), ('of', 'IN'), ('course', 'NN'), ('the', 'DT'), ('last', 'JJ'), ('things', 'NNS'), ('that', 'IN'), ('you', 'PRP'), ('really', 'RB'), ('want', 'VBP'), ('at', 'IN'), ('the', 'DT'), ('end', 'NN'), ('of', 'IN'), ('a', 'DT'), ('hard', 'JJ'), ('day', 'NN'), ('of', 'IN'), ('traveling', 'VBG'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=9, context=[('no', 'DT'), ('one', 'PRP'), ('could', 'MD'), ('have', 'VB'), ('been', 'VBN'), ('more', 'RBR'), ('courageous', 'JJ'), (',', ','), ('more', 'RBR'), ('hard', 'JJ'), ('working', 'NN'), (',', ','), ('more', 'RBR'), ('fair-minded', 'JJ'), (',', ','), ('more', 'RBR'), ('amiable', 'JJ'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=3, context=[('a', 'DT'), ('clearer', 'JJR'), (',', ','), ('harder', 'JJ'), (',', ','), ('tougher', 'RBR'), ('national', 'JJ'), ('self-assessment', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=14, context=[('davies', 'NNP'), ('said', 'VBD'), ('authorities', 'NNS'), ('here', 'RB'), ('had', 'VBD'), ('long', 'RB'), ('suspected', 'VBN'), ('sjonborg', 'NNP'), ('in', 'IN'), ('wilde', 'NNP'), ("'s", 'POS'), ('slaying', 'NN'), ('but', 'CC'), ('lacked', 'VBD'), ('hard', 'JJ'), ('evidence', 'NN'), ('until', 'IN'), ('his', 'PRP$'), ('estranged', 'VBN'), ('wife', 'NN'), ('came', 'VBD'), ('forward', 'RB'), ('sept', 'NNP'), ('.', '.'), ('6', 'CD'), ('and', 'CC'), ('recanted', 'VBD'), ('an', 'DT'), ('earlier', 'JJR'), ('alibi', 'NN'), ('she', 'PRP'), ('had', 'VBD'), ('given', 'VBN'), ('sjonborg', 'NNP'), ('for', 'IN'), ('the', 'DT'), ('day', 'NN'), ('of', 'IN'), ('wilde', 'NNP'), ("'s", 'POS'), ('death', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=5, context=[('your', 'PRP$'), ('self-discipline', 'NN'), (',', ','), ('diligence', 'NN'), ('and', 'CC'), ('hard', 'JJ'), ('work', 'NN'), ('are', 'VBP'), ('exemplary', 'JJ'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=9, context=[('they', 'PRP'), ('look', 'VBP'), ('old', 'JJ'), ('and', 'CC'), ('dumpy', 'JJ'), (',', ','), ('with', 'IN'), ('stolid', 'JJ'), (',', ','), ('hard', 'JJ'), ('faces', 'NNS'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=14, context=[('i', 'PRP'), ('don', 'VBP'), ("'t", 'VBG'), ('know', 'NN'), ('if', 'IN'), ('you', 'PRP'), ('would', 'MD'), ('call', 'VB'), ('it', 'PRP'), ('luck', 'NN'), (',', ','), ('or', 'CC'), ('just', 'RB'), ('plain', 'JJ'), ('hard', 'JJ'), ('work', 'NN'), ('--', ':'), ('it', 'PRP'), ('was', 'VBD'), ('probably', 'RB'), ('a', 'DT'), ('combination', 'NN'), ('of', 'IN'), ('both', 'DT'), ('--', ':'), ('but', 'CC'), ('your', 'PRP$'), ('mother', 'NN'), ('and', 'CC'), ('i', 'PRP'), ('put', 'VBP'), ('in', 'IN'), ('a', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('hours', 'NNS'), ('and', 'CC'), ('ended', 'VBD'), ('up', 'IN'), ('with', 'IN'), ('a', 'DT'), ('very', 'RB'), ('successful', 'JJ'), ('business', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=2, context=[('it', 'PRP'), ('was', 'VBD'), ('hard', 'JJ'), ('work', 'NN'), (',', ','), ('recalls', 'VBZ'), ('john', 'NNP'), ('a', 'DT'), ('.', '.'), ('breeding', 'NNP'), (',', ','), ('a', 'DT'), ('year', 'NN'), ('younger', 'JJR'), ('than', 'IN'), ('lester', 'NNP'), ('and', 'CC'), ('now', 'RB'), ('a', 'DT'), ('resident', 'NN'), ('of', 'IN'), ('live', 'NNP'), ('oak', 'NNP'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=20, context=[('the', 'DT'), ('hearings', 'NNS'), ('forced', 'VBD'), ('tim', 'NNP'), ('stead', 'NNP'), (',', ','), ('37', 'CD'), (',', ','), ('a', 'DT'), ('supervisor', 'NN'), ('at', 'IN'), ('a', 'DT'), ('san', 'NNP'), ('jose', 'NNP'), ('manufacturing', 'NN'), ('plant', 'NN'), (',', ','), ('to', 'TO'), ('take', 'VB'), ('a', 'DT'), ('hard', 'JJ'), ('look', 'NN'), ('at', 'IN'), ('his', 'PRP$'), ('past', 'JJ'), ('treatment', 'NN'), ('of', 'IN'), ('women', 'NNS'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=8, context=[('she', 'PRP'), ('said', 'VBD'), ('mr', 'NNP'), ('.', '.'), ('daly', 'NNP'), ('was', 'VBD'), ('``', '``'), ('a', 'DT'), ('hard', 'JJ'), ('news', 'NN'), ('man', 'NN'), ("''", "''"), ('who', 'WP'), ('had', 'VBD'), ('become', 'VBN'), ('dismayed', 'VBN'), ('by', 'IN'), ('recent', 'JJ'), ('trends', 'NNS'), ('in', 'IN'), ('journalism', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=11, context=[('if', 'IN'), ('others', 'NNS'), ('in', 'IN'), ('silicon', 'NNP'), ('valley', 'NNP'), ('are', 'VBP'), ('encouraged', 'VBN'), ('and', 'CC'), ('richly', 'RB'), ('rewarded', 'VBN'), ('for', 'IN'), ('hard', 'JJ'), ('work', 'NN'), ('and', 'CC'), ('perseverance', 'NN'), (',', ','), ('why', 'WRB'), ('should', 'MD'), ('teachers', 'NNS'), ('be', 'VB'), ('singled', 'VBN'), ('out', 'IN'), ('and', 'CC'), ('condemned', 'VBN'), ('?', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=43, context=[('even', 'RB'), ('with', 'IN'), ('its', 'PRP$'), ('joyous', 'JJ'), ('moments', 'NNS'), (',', ','), ('songs', 'NNS'), ('such', 'JJ'), ('as', 'IN'), ('``', '``'), ('something', 'NN'), ('to', 'TO'), ('talk', 'VB'), ('about', 'IN'), (',', ','), ('"', '"'), ('``', '``'), ('good', 'JJ'), ('man', 'NN'), (',', ','), ('good', 'NNP'), ('woman', 'NNP'), ("''", "''"), ('and', 'CC'), ('the', 'DT'), ('sultry', 'JJ'), ('``', '``'), ('slow', 'JJ'), ('ride', 'VB'), (',', ','), ('"', '"'), ('``', '``'), ('luck', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('draw', 'VB'), ("''", "''"), ('asks', 'VBZ'), ('tough', 'JJ'), ('questions', 'NNS'), ('and', 'CC'), ('takes', 'VBZ'), ('a', 'DT'), ('hard', 'JJ'), ('look', 'NN'), ('at', 'IN'), ('the', 'DT'), ('never-ending', 'JJ'), ('balance', 'NN'), ('between', 'IN'), ('ideals', 'NNS'), ('and', 'CC'), ('realities', 'NNS'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=4, context=[('but', 'CC'), ('the', 'DT'), ('administration', 'NN'), ('wants', 'VBZ'), ('hard', 'JJ'), ('evidence', 'NN'), ('the', 'DT'), ('soviets', 'NNPS'), ('are', 'VBP'), ('moving', 'VBG'), ('to', 'TO'), ('a', 'DT'), ('free', 'JJ'), ('market', 'NN'), ('economy', 'NN'), (',', ','), ('before', 'IN'), ('more', 'RBR'), ('massive', 'JJ'), ('aid', 'NN'), ('is', 'VBZ'), ('considered', 'VBN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=32, context=[('proposing', 'VBG'), ('the', 'DT'), ('toast', 'NN'), ('of', 'IN'), ('the', 'DT'), ('guests', 'NNS'), (',', ','), ('mr', 'NNP'), ('thomas', 'NNP'), ('lonsdale', 'NNP'), (',', ','), ('said', 'VBD'), ('the', 'DT'), ('catering', 'NN'), ('industry', 'NN'), ('today', 'NN'), ('required', 'VBD'), ('brains', 'NNS'), (',', ','), ('but', 'CC'), ('pointed', 'VBD'), ('out', 'RP'), ('that', 'IN'), ('the', 'DT'), ('capacity', 'NN'), ('to', 'TO'), ('absorb', 'VB'), ('technical', 'JJ'), ('knowledge', 'NN'), ('differed', 'VBD'), ('from', 'IN'), ('the', 'DT'), ('hard', 'JJ'), ('realism', 'NN'), ('of', 'IN'), ('routine', 'JJ'), ('catering', 'NN'), (',', ','), ('which', 'WDT'), ('demanded', 'VBD'), ('not', 'RB'), ('only', 'JJ'), ('brains', 'NNS'), ('and', 'CC'), ('skill', 'NN'), (',', ','), ('but', 'CC'), ('common', 'JJ'), ('sense', 'NN'), ('and', 'CC'), ('understanding', 'NN'), ('of', 'IN'), ('human', 'JJ'), ('nature', 'NN'), ('as', 'RB'), ('well', 'RB'), ('as', 'IN'), ('the', 'DT'), ('highest', 'JJS'), ('possible', 'JJ'), ('degree', 'NN'), ('of', 'IN'), ('courtesy', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=4, context=[('to', 'TO'), ('the', 'DT'), ('mix', 'NN'), ('of', 'IN'), ('hard', 'JJ'), ('facts', 'NNS'), (',', ','), ('horoscopes', 'NNS'), ('and', 'CC'), ('advice', 'NN'), ('offered', 'VBN'), ('at', 'IN'), ('the', 'DT'), ('end', 'NN'), ('of', 'IN'), ('900', 'CD'), ('lines', 'NNS'), (',', ','), ('a', 'DT'), ('group', 'NN'), ('of', 'IN'), ('mainline', 'JJ'), ('christians', 'NNPS'), ('is', 'VBZ'), ('adding', 'VBG'), ('another', 'DT'), ('choice', 'NN'), (':', ':'), ('comfort', 'NN'), ('and', 'CC'), ('inspiration', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=5, context=[('wilson', 'NNP'), ('needs', 'VBZ'), ('to', 'TO'), ('take', 'VB'), ('a', 'DT'), ('hard', 'JJ'), ('look', 'NN'), ('at', 'IN'), ('just', 'RB'), ('how', 'WRB'), ('the', 'DT'), ('state', 'NN'), ('is', 'VBZ'), ('spending', 'VBG'), ('its', 'PRP$'), ('resources', 'NNS'), ('when', 'WRB'), ('it', 'PRP'), ('comes', 'VBZ'), ('to', 'TO'), ('the', 'DT'), ('poor', 'NN'), (',', ','), ('elderly', 'JJ'), ('and', 'CC'), ('disabled', 'JJ'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=8, context=[('our', 'PRP$'), ('grandmothers', 'NNS'), ('might', 'MD'), ('have', 'VB'), ('described', 'VBN'), ('her', 'PRP'), ('as', 'IN'), ('a', 'DT'), ('hard', 'JJ'), ('woman', 'NN'), (',', ','), ('but', 'CC'), ('today', 'NN'), ('she', 'PRP'), ('was', 'VBD'), ('trying', 'VBG'), ('desperately', 'RB'), ('to', 'TO'), ('recapture', 'VB'), ('yesterday', 'NN'), ("'s", 'POS'), ('ingenue', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=4, context=[('the', 'DT'), ('clouds', 'NNS'), ('parted', 'VBD'), ('and', 'CC'), ('hard', 'JJ'), ('gashes', 'NNS'), ('of', 'IN'), ('sunlight', 'NN'), ('swooped', 'VBD'), ('down', 'RB'), ('to', 'TO'), ('stain', 'VB'), ('the', 'DT'), ('earth', 'NN'), ('with', 'IN'), ('streaks', 'NNS'), ('of', 'IN'), ('white', 'NN'), ('and', 'CC'), ('gold', 'NN'), ('light', 'NN'), ('so', 'RB'), ('that', 'IN'), ('the', 'DT'), ('shadows', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('running', 'VBG'), ('horses', 'NNS'), ('flowed', 'VBD'), ('like', 'IN'), ('dark', 'JJ'), ('streams', 'NNS'), ('over', 'IN'), ('the', 'DT'), ('dazzling', 'JJ'), ('snow', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=9, context=[('her', 'PRP$'), ('friend', 'NN'), ('commiserates', 'VBZ'), (':', ':'), ('``', '``'), ('no', 'DT'), ('way', 'NN'), ('to', 'TO'), ('avoid', 'VB'), ('hard', 'JJ'), ('work', 'NN'), ('.', '.'), ("''", "''")], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=6, context=[('fellow', 'NN'), ('council', 'NN'), ('members', 'NNS'), ('praised', 'VBD'), ('rogers', 'NNP'), ('for', 'IN'), ('hard', 'JJ'), ('work', 'NN'), ('and', 'CC'), ('dedication', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=2, context=[('professors', 'NNP'), ('in', 'IN'), ('hard', 'JJ'), ('science', 'NN'), ('disciplines', 'NNS'), (',', ','), ('such', 'JJ'), ('as', 'IN'), ('engineering', 'NN'), (',', ','), ('were', 'VBD'), ('found', 'VBN'), ('to', 'TO'), ('be', 'VB'), ('more', 'RBR'), ('satisfied', 'VBN'), ('with', 'IN'), ('their', 'PRP$'), ('jobs', 'NNS'), ('than', 'IN'), ('their', 'PRP$'), ('colleagues', 'NNS'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=45, context=[('some', 'DT'), ('of', 'IN'), ('the', 'DT'), ('lime', 'NN'), ('that', 'WDT'), ('is', 'VBZ'), ('always', 'RB'), ('on', 'IN'), ('hand', 'NN'), ('in', 'IN'), ('the', 'DT'), ('capitol', 'NNP'), ('basement', 'NN'), ('for', 'IN'), ('plaster', 'NN'), ('repairs', 'NNS'), ('was', 'VBD'), ('slaked', 'VBN'), ('several', 'JJ'), ('months', 'NNS'), ('for', 'IN'), ('us', 'PRP'), (';', ':'), ('but', 'CC'), ('to', 'TO'), ('make', 'VB'), ('it', 'PRP'), ('stiffer', 'JJR'), (',', ','), ('of', 'IN'), ('a', 'DT'), ('really', 'RB'), ('putty-like', 'JJ'), ('consistency', 'NN'), ('to', 'TO'), ('avoid', 'VB'), ('cracking', 'VBG'), (',', ','), ('we', 'PRP'), ('added', 'VBD'), ('a', 'DT'), ('little', 'JJ'), ('hydrated', 'JJ'), ('lime', 'NN'), ('-', ':'), ('hard', 'JJ'), ('on', 'IN'), ('the', 'DT'), ('hands', 'NNS'), (',', ','), ('but', 'CC'), ('we', 'PRP'), ('could', 'MD'), ('see', 'VB'), ('no', 'DT'), ('other', 'JJ'), ('disadvantage', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=4, context=[('i', 'PRP'), ('invite', 'VBP'), ('anyone', 'NN'), ('with', 'IN'), ('hard', 'JJ'), ('information', 'NN'), ('from', 'IN'), ('kuwait', 'NNP'), ('that', 'WDT'), ('contradicts', 'VBZ'), ('our', 'PRP$'), ('preliminary', 'JJ'), ('findings', 'NNS'), ('to', 'TO'), ('get', 'VB'), ('it', 'PRP'), ('to', 'TO'), ('us', 'PRP'), ('as', 'RB'), ('quickly', 'RB'), ('as', 'IN'), ('possible', 'JJ'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=21, context=[('evidently', 'RB'), (',', ','), ('when', 'WRB'), ('you', 'PRP'), ('came', 'VBD'), ('up', 'IN'), ('with', 'IN'), ('the', 'DT'), ('solution', 'NN'), ('of', 'IN'), ('owning', 'VBG'), ('your', 'PRP$'), ('own', 'JJ'), ('home', 'NN'), (',', ','), ('you', 'PRP'), ('forgot', 'VBD'), ('to', 'TO'), ('add', 'VB'), ('patience', 'NN'), ('to', 'TO'), ('hard', 'JJ'), ('work', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=15, context=[('and', 'CC'), ('so', 'IN'), ('you', 'PRP'), ('did', 'VBD'), ('of', 'IN'), ('me', 'PRP'), (',', ','), ('jane', 'NNP'), ('thought', 'VBD'), (',', ','), ('with', 'IN'), ('a', 'DT'), ('sudden', 'JJ'), (',', ','), ('uncharacteristically', 'RB'), ('hard', 'JJ'), ('perception', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=25, context=[('the', 'DT'), ('chevy', 'NNP'), ('engined', 'VBD'), ('stalled', 'VBN'), (',', ','), ('mears', 'NNP'), ('said', 'VBD'), (',', ','), ('because', 'IN'), ('it', 'PRP'), ('failed', 'VBD'), ('to', 'TO'), ('pick', 'VB'), ('up', 'IN'), ('fuel', 'NN'), ('after', 'IN'), ('mears', 'NNP'), ('took', 'VBD'), ('it', 'PRP'), ('down', 'RP'), ('the', 'DT'), ('hill', 'NN'), ('and', 'CC'), ('made', 'VBD'), ('the', 'DT'), ('hard', 'JJ'), ('left', 'VBN'), ('turn', 'VB'), ('toward', 'IN'), ('the', 'DT'), ('checkered', 'VBN'), ('flag', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=11, context=[('``', '``'), ('it', 'PRP'), ("'s", 'VBZ'), ('a', 'DT'), ('force', 'NN'), ('that', 'WDT'), ("'s", 'VBZ'), ('designed', 'VBN'), ('to', 'TO'), ('take', 'VB'), ('a', 'DT'), ('hard', 'JJ'), ('look', 'NN'), ('at', 'IN'), ('the', 'DT'), ('capabilities', 'NNS'), ('of', 'IN'), ('potential', 'JJ'), ('opponents', 'NNS'), ('around', 'IN'), ('the', 'DT'), ('world', 'NN'), ('.', '.'), ("''", "''")], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=3, context=[('``', '``'), ('all', 'DT'), ('that', 'NN'), ('hard', 'JJ'), ('work', 'NN'), ('i', 'PRP'), ('did', 'VBD'), ('in', 'IN'), ('spring', 'NN'), ('training', 'NN'), ('paid', 'VBN'), ('off', 'IN'), ('.', '.'), ('.', '.'), ('.', '.'), ("''", "''")], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=6, context=[('he', 'PRP'), ('said', 'VBD'), ('tuesday', 'NNP'), ('there', 'EX'), ('are', 'VBP'), ('no', 'DT'), ('hard', 'JJ'), ('feelings', 'NNS'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=38, context=[('while', 'IN'), ('not', 'RB'), ('denying', 'VBG'), ('his', 'PRP$'), ('obvious', 'JJ'), ('sex', 'NN'), ('appeal', 'NN'), (',', ','), ('bolton', 'NNP'), ('has', 'VBZ'), ('clearly', 'RB'), ('earned', 'VBN'), ('his', 'PRP$'), ('position', 'NN'), ('of', 'IN'), ('prominence', 'NN'), (',', ','), ('artistically', 'RB'), ('and', 'CC'), ('commercially', 'RB'), (',', ','), ('in', 'IN'), ('the', 'DT'), ('music', 'NN'), ('industry', 'NN'), ('through', 'IN'), ('his', 'PRP$'), ('tremendous', 'JJ'), ('talents', 'NNS'), ('as', 'IN'), ('a', 'DT'), ('singer', 'NN'), ('and', 'CC'), ('songwriter', 'NN'), ('and', 'CC'), ('many', 'JJ'), ('years', 'NNS'), ('of', 'IN'), ('hard', 'JJ'), ('work', 'NN'), ('and', 'CC'), ('dedication', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=3, context=[('yet', 'RB'), (',', ','), ('with', 'IN'), ('hard', 'JJ'), ('work', 'NN'), ('and', 'CC'), ('the', 'DT'), ('ability', 'NN'), ('to', 'TO'), ('live', 'VB'), ('within', 'IN'), ('their', 'PRP$'), ('means', 'NNS'), (',', ','), ('they', 'PRP'), ('have', 'VBP'), ('produced', 'VBN'), ('what', 'WP'), ('is', 'VBZ'), ('seen', 'VBN'), ('now', 'RB'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=7, context=[('but', 'CC'), ('when', 'WRB'), ('she', 'PRP'), ('finished', 'VBD'), ('his', 'PRP$'), ('eyes', 'NNS'), ('were', 'VBD'), ('hard', 'JJ'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=10, context=[('corporate', 'JJ'), ('information', 'NN'), ('systems', 'NNS'), ('managers', 'NNS'), ('need', 'VBP'), ('to', 'TO'), ('take', 'VB'), ('a', 'DT'), ('good', 'NN'), (',', ','), ('hard', 'JJ'), ('look', 'NN'), ('at', 'IN'), ('what', 'WP'), ('people', 'NNS'), ('need', 'VBP'), ('and', 'CC'), ('then', 'RB'), ('develop', 'VB'), ('simple', 'JJ'), (',', ','), ('useful', 'JJ'), ('applications', 'NNS'), ('that', 'WDT'), ('deliver', 'VBP'), ('up-to-date', 'JJ'), ('information', 'NN'), ('into', 'IN'), ('knowledge', 'NN'), ('workers', 'NNS'), ("'", 'POS'), ('hands', 'NNS'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=3, context=[('however', 'RB'), (',', ','), ('a', 'DT'), ('hard', 'JJ'), ('look', 'NN'), ('at', 'IN'), ('the', 'DT'), ('current', 'JJ'), ('career', 'NN'), ('path', 'NN'), ('system', 'NN'), ('shows', 'VBZ'), ('that', 'IN'), ('it', 'PRP'), ('does', 'VBZ'), ('not', 'RB'), ('work', 'VB'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=11, context=[('``', '``'), ('so', 'RB'), (',', ','), ('for', 'IN'), ('the', 'DT'), ('time', 'NN'), ('being', 'VBG'), (',', ','), ('adios', 'NNS'), (',', ','), ('no', 'DT'), ('hard', 'JJ'), ('feelings', 'NNS'), ('.', '.'), ("''", "''")], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=8, context=[('all', 'DT'), ('californians', 'NNS'), ('need', 'VBP'), ('to', 'TO'), ('take', 'VB'), ('a', 'DT'), ('long', 'JJ'), (',', ','), ('hard', 'JJ'), ('look', 'NN'), ('into', 'IN'), ('themselves', 'PRP'), ('and', 'CC'), ('stop', 'VB'), ('hiding', 'VBG'), ('behind', 'IN'), ('fuzzy', 'JJ'), (',', ','), ('``', '``'), ('liberated', 'VBN'), ("''", "''"), ('notions', 'NNS'), ('of', 'IN'), ('freedom', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=19, context=[('home', 'NNP'), (':', ':'), ('a', 'DT'), ('``', '``'), ('rustic', 'JJ'), ("''", "''"), ('older', 'JJR'), ('home', 'NN'), ('on', 'IN'), ('four', 'CD'), ('acres', 'NNS'), ('in', 'IN'), ('woodside', 'NNP'), ('that', 'WDT'), ('gets', 'VBZ'), ('a', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('``', '``'), ('hard', 'JJ'), ("''", "''"), ('use', 'NN'), (',', ','), ('he', 'PRP'), ('says', 'VBZ'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=10, context=[('these', 'DT'), ('people', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('backers', 'NNS'), ('played', 'VBD'), ('no', 'DT'), ('part', 'NN'), ('in', 'IN'), ('the', 'DT'), ('hard', 'JJ'), ('work', 'NN'), ('of', 'IN'), ('collecting', 'VBG'), ('19', 'CD'), (',', ','), ('000', 'CD'), ('signatures', 'NNS'), ('for', 'IN'), ('recall', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=23, context=[('the', 'DT'), ('brother', 'NN'), ('and', 'CC'), ('sister', 'NN'), ('seemed', 'VBD'), ('to', 'TO'), ('be', 'VB'), ('a', 'DT'), ('sort', 'NN'), ('of', 'IN'), ('mutual-aid', 'JJ'), ('society', 'NN'), (',', ','), ('a', 'DT'), ('little', 'JJ'), ('fortress', 'NN'), ('of', 'IN'), ('kindness', 'NN'), ('for', 'IN'), ('each', 'DT'), ('other', 'NN'), ('in', 'IN'), ('a', 'DT'), ('hard', 'JJ'), ('world', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=6, context=[('disagreement', 'NN'), ('over', 'IN'), ('other', 'JJ'), ('matters', 'NNS'), ('has', 'VBZ'), ('kept', 'VBN'), ('hard', 'JJ'), ('feelings', 'NNS'), ('from', 'IN'), ('dying', 'VBG'), (',', ','), ('she', 'PRP'), ('said', 'VBD'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=11, context=[('in', 'IN'), ('its', 'PRP$'), ('cover', 'NN'), ('piece', 'NN'), (',', ','), ('the', 'DT'), ('current', 'JJ'), ('people', 'NNS'), ('magazine', 'NN'), ('takes', 'VBZ'), ('a', 'DT'), ('hard', 'JJ'), ('look', 'NN'), ('at', 'IN'), ('the', 'DT'), ('pair', 'NN'), (',', ','), ('who', 'WP'), ('don', 'VBP'), ("'t", 'VBG'), ('see', 'VB'), ('each', 'DT'), ('other', 'JJ'), ('very', 'RB'), ('often', 'RB'), ('anymore', 'RB'), ('--', ':'), ('at', 'IN'), ('one', 'CD'), ('point', 'NN'), ('royal', 'JJ'), ('watchers', 'NNS'), ('figured', 'VBD'), ('they', 'PRP'), ('had', 'VBD'), ('n', 'NN'), ("'t", 'NN'), ('been', 'VBN'), ('together', 'RB'), ('for', 'IN'), ('39', 'CD'), ('days', 'NNS'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=18, context=[('``', '``'), ('pro', 'NNP'), ('athletes', 'NNS'), ('never', 'RB'), ('know', 'VBP'), ('how', 'WRB'), ('good', 'JJ'), ('they', 'PRP'), ('have', 'VBP'), ('it', 'PRP'), ('until', 'IN'), ('they', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('face', 'VB'), ('some', 'DT'), ('kind', 'NN'), ('of', 'IN'), ('hard', 'JJ'), ('reality', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=6, context=[('yuh', 'NNP'), ('25', 'CD'), (',', ','), ('unaccustomed', 'JJ'), ('to', 'TO'), ('the', 'DT'), ('hard', 'JJ'), ('edge', 'NN'), ('of', 'IN'), ('new', 'NNP'), ('york', 'NNP'), ('humor', 'NN'), (',', ','), ('found', 'VBD'), ('breslin', 'NNP'), ("'s", 'POS'), ('remarks', 'NNS'), ('sexist', 'JJ'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=3, context=[('school', 'NN'), ('discipline', 'NN'), (',', ','), ('hard', 'JJ'), ('work', 'NN'), ('and', 'CC'), ('right-from-wrong', 'NN'), ('were', 'VBD'), ('of', 'IN'), ('the', 'DT'), ('highest', 'JJS'), ('priority', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=28, context=[('ironically', 'RB'), (',', ','), ('she', 'PRP'), ('says', 'VBZ'), (',', ','), ('just', 'RB'), ('when', 'WRB'), ('her', 'PRP$'), ('consulting', 'NN'), ('business', 'NN'), ('is', 'VBZ'), ('firmly', 'RB'), ('established', 'VBN'), ('and', 'CC'), ('could', 'MD'), ('be', 'VB'), ('run', 'VBN'), ('from', 'IN'), ('any', 'DT'), ('location', 'NN'), (',', ','), ('the', 'DT'), ('couple', 'NN'), ('are', 'VBP'), ('taking', 'VBG'), ('a', 'DT'), ('long', 'JJ'), (',', ','), ('hard', 'JJ'), ('look', 'NN'), ('at', 'IN'), ('each', 'DT'), ('one', 'CD'), ("'s", 'POS'), ('career', 'NN'), ('potential', 'JJ'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=23, context=[('``', '``'), ('i', 'PRP'), ("'m", 'VBP'), ('here', 'RB'), ('to', 'TO'), ('do', 'VB'), ('my', 'PRP$'), ('job', 'NN'), (',', ','), ('and', 'CC'), ('that', 'DT'), ("'s", 'VBZ'), ('it', 'PRP'), (',', ','), ('"', '"'), ('said', 'VBD'), ('dickerson', 'NNP'), (',', ','), ('who', 'WP'), ('admitted', 'VBD'), ('he', 'PRP'), ('still', 'RB'), ('has', 'VBZ'), ('hard', 'JJ'), ('feelings', 'NNS'), ('toward', 'IN'), ('the', 'DT'), ('colts', 'NNP'), ("'", 'POS'), ('management', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=8, context=[('but', 'CC'), ('on', 'IN'), ('sunday', 'NNP'), (',', ','), ('after', 'IN'), ('two', 'CD'), ('weeks', 'NNS'), ('of', 'IN'), ('hard', 'JJ'), ('thinking', 'NN'), (',', ','), ('blondie', 'NNP'), ('bumstead', 'NNP'), ('entered', 'VBD'), ('the', 'DT'), ('workforce', 'NN'), ('as', 'IN'), ('.', '.'), ('.', '.'), ('.', '.'), ('a', 'DT'), ('caterer', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=9, context=[('but', 'CC'), ('industry', 'NN'), ('analysts', 'NNS'), ('in', 'IN'), ('japan', 'NNP'), ('say', 'VBP'), ('ibm', 'NNP'), ('faces', 'VBZ'), ('a', 'DT'), ('hard', 'JJ'), ('fight', 'NN'), ('in', 'IN'), ('the', 'DT'), ('japanese', 'JJ'), ('market', 'NN'), (',', ','), ('where', 'WRB'), ('price', 'NN'), ('competition', 'NN'), ('for', 'IN'), ('notebook', 'NN'), ('computers', 'NNS'), ('is', 'VBZ'), ('fierce', 'JJ'), ('and', 'CC'), ('loyalty', 'NN'), ('to', 'TO'), ('japanese', 'JJ'), ('brands', 'NNS'), ('runs', 'VBZ'), ('deep', 'JJ'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=6, context=[('even', 'RB'), ('the', 'DT'), ('most', 'RBS'), ('radical', 'JJ'), ('professors', 'NNS'), ('require', 'VBP'), ('hard', 'JJ'), ('work', 'NN'), ('and', 'CC'), ('self-reliance', 'NN'), ('from', 'IN'), ('their', 'PRP$'), ('students', 'NNS'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=16, context=[('further', 'RB'), (',', ','), ('any', 'DT'), ('institution', 'NN'), ('that', 'WDT'), ("'s", 'VBZ'), ('got', 'VBD'), ('real', 'JJ'), ('estate', 'NN'), ('and', 'CC'), ('oil', 'NN'), ('and', 'CC'), ('gas', 'NN'), ('and', 'CC'), ('takes', 'VBZ'), ('a', 'DT'), ('hard', 'JJ'), ('look', 'NN'), ('at', 'IN'), ('it', 'PRP'), ('this', 'DT'), ('year', 'NN'), ('and', 'CC'), ('does', 'VBZ'), ('n', 'NN'), ("'t", 'NN'), ('write', 'VB'), ('it', 'PRP'), ('down', 'RB'), ('has', 'VBZ'), ('a', 'DT'), ('very', 'RB'), ('peculiar', 'JJ'), ('portfolio', 'NN'), (',', ','), ('"', '"'), ('meyer', 'NNP'), ('said', 'VBD'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=12, context=[('the', 'DT'), ('best', 'JJS'), ('antidote', 'NN'), ('for', 'IN'), ('the', 'DT'), ('bitterness', 'NN'), ('and', 'CC'), ('disappointment', 'NN'), ('that', 'WDT'), ('poisoned', 'VBD'), ('him', 'PRP'), ('was', 'VBD'), ('hard', 'JJ'), ('work', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=7, context=[('corrections', 'NNP'), ('counselor', 'NN'), ('ric', 'NNP'), ('hyland', 'NNP'), (',', ','), ('who', 'WP'), ('did', 'VBD'), ('hard', 'JJ'), ('time', 'NN'), ('for', 'IN'), ('armed', 'VBN'), ('robbery', 'NN'), ('25', 'CD'), ('years', 'NNS'), ('ago', 'RB'), (',', ','), ('stood', 'VBD'), ('shoulder', 'NN'), ('to', 'TO'), ('shoulder', 'VB'), ('with', 'IN'), ('the', 'DT'), ('31-year-old', 'JJ'), ('groom', 'NN'), (',', ','), ('whose', 'WP$'), ('criminal', 'JJ'), ('record', 'NN'), ('includes', 'VBZ'), ('42', 'CD'), ('misdemeanor', 'NN'), ('and', 'CC'), ('four', 'CD'), ('felony', 'NN'), ('convictions', 'NNS'), ('for', 'IN'), ('drug', 'NN'), ('and', 'CC'), ('alcohol', 'NN'), ('-', ':'), ('related', 'VBN'), ('crimes', 'NNS'), ('and', 'CC'), ('three', 'CD'), ('terms', 'NNS'), ('in', 'IN'), ('san', 'NNP'), ('quentin', 'NNP'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=4, context=[('demure', 'JJ'), ('one', 'CD'), ('moment', 'NN'), (',', ','), ('hard', 'JJ'), ('and', 'CC'), ('decisive', 'JJ'), ('the', 'DT'), ('next', 'JJ'), (',', ','), ('she', 'PRP'), ('caught', 'VBD'), ('the', 'DT'), ('dual', 'JJ'), ('sides', 'NNS'), ('of', 'IN'), ('a', 'DT'), ('complex', 'JJ'), ('character', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=1, context=[('but', 'CC'), ('hard', 'JJ'), ('work', 'NN'), (',', ','), ('he', 'PRP'), ('concludes', 'VBZ'), (',', ','), ('is', 'VBZ'), ('n', 'NN'), ("'t", 'NN'), ('sufficient', 'JJ'), ('to', 'TO'), ('recover', 'VB'), ('or', 'CC'), ('create', 'VB'), ('a', 'DT'), ('winning', 'VBG'), ('formula', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=28, context=[('parents', 'NNS'), ('perhaps', 'RB'), ('fall', 'VBP'), ('into', 'IN'), ('three', 'CD'), ('sections', 'NNS'), (';', ':'), ('those', 'DT'), ('who', 'WP'), ('were', 'VBD'), ('glad', 'JJ'), ('to', 'TO'), ('finish', 'VB'), ('formal', 'JJ'), ('education', 'NN'), ('at', 'IN'), ('14', 'CD'), ('or', 'CC'), ('earlier', 'RBR'), (',', ','), ('those', 'DT'), ('who', 'WP'), ('obtained', 'VBD'), ('a', 'DT'), ('professional', 'JJ'), ('qualification', 'NN'), ('``', '``'), ('the', 'DT'), ('hard', 'JJ'), ('way', 'NN'), ("''", "''"), ('under', 'IN'), ('the', 'DT'), ('traditional', 'JJ'), ('english', 'NNP'), ('system', 'NN'), (',', ','), ('and', 'CC'), ('those', 'DT'), ('who', 'WP'), ('remember', 'VBP'), ('their', 'PRP$'), ('own', 'JJ'), ('university', 'NNP'), ('-', ':'), ('and', 'CC'), ('for', 'IN'), ('most', 'RBS'), ('this', 'DT'), ('would', 'MD'), ('be', 'VB'), ('oxford', 'NNP'), (',', ','), ('cambridge', 'NNP'), ('or', 'CC'), ('a', 'DT'), ('london', 'NNP'), ('medical', 'JJ'), ('school', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=24, context=[('attorneys', 'NNS'), ('for', 'IN'), ('william', 'NNP'), ('lucas', 'NNP'), ('barker', 'NNP'), ('were', 'VBD'), ('unsuccessful', 'JJ'), ('in', 'IN'), ('their', 'PRP$'), ('bid', 'NN'), ('to', 'TO'), ('have', 'VB'), ('their', 'PRP$'), ('client', 'NN'), ("'s", 'POS'), ('charges', 'NNS'), ('dismissed', 'VBD'), ('on', 'IN'), ('the', 'DT'), ('grounds', 'NNS'), ('that', 'IN'), ('there', 'EX'), ('is', 'VBZ'), ('no', 'DT'), ('hard', 'JJ'), ('scientific', 'JJ'), ('proof', 'NN'), ('that', 'IN'), ('he', 'PRP'), ('has', 'VBZ'), ('aids', 'NNP'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=51, context=[('recently', 'RB'), ('at', 'IN'), ('a', 'DT'), ('workshop', 'NN'), ('of', 'IN'), ('tri-valley', 'NNP'), ('citizens', 'NNPS'), ('against', 'IN'), ('a', 'DT'), ('radioactive', 'NNP'), ('environment', 'NNP'), (',', ','), ('i', 'PRP'), ('heard', 'VBD'), ('a', 'DT'), ('physicist', 'NN'), ('from', 'IN'), ('the', 'DT'), ('lab', 'NN'), ('comment', 'NN'), ('that', 'IN'), ('the', 'DT'), ('project', 'NN'), ('may', 'MD'), ('well', 'RB'), ('be', 'VB'), ('mothballed', 'VBN'), ('after', 'IN'), ('completion', 'NN'), ('because', 'IN'), ('the', 'DT'), ('soviets', 'NNPS'), ('already', 'RB'), ('have', 'VBP'), ('much', 'JJ'), ('excess', 'JJ'), ('capacity', 'NN'), ('to', 'TO'), ('produce', 'VB'), ('enriched', 'VBN'), ('uranium', 'NN'), ('using', 'VBG'), ('other', 'JJ'), ('technology', 'NN'), ('and', 'CC'), (',', ','), ('given', 'VBN'), ('their', 'PRP$'), ('desperate', 'JJ'), ('need', 'NN'), ('for', 'IN'), ('hard', 'JJ'), ('currency', 'NN'), (',', ','), ('they', 'PRP'), ('would', 'MD'), ('be', 'VB'), ('willing', 'JJ'), ('to', 'TO'), ('undersell', 'VB'), ('anyone', 'NN'), ('on', 'IN'), ('the', 'DT'), ('planet', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=6, context=[('the', 'DT'), ('task', 'NN'), ('force', 'NN'), ('will', 'MD'), ('take', 'VB'), ('a', 'DT'), ('hard', 'JJ'), ('look', 'NN'), ('at', 'IN'), ('the', 'DT'), ('funding', 'NN'), (',', ','), ('programming', 'NN'), ('and', 'CC'), ('academic', 'JJ'), ('support', 'NN'), ('sjs', 'NNP'), ('must', 'MD'), ('have', 'VB'), ('to', 'TO'), ('enhance', 'VB'), ('a', 'DT'), ('division', 'NNP'), ('i', 'PRP'), ('program', 'VBP'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=3, context=[('thanks', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('hard', 'JJ'), ('work', 'NN'), ('of', 'IN'), ('diligent', 'JJ'), ('researchers', 'NNS'), (',', ','), ('the', 'DT'), ('classic', 'JJ'), ('two-reel', 'JJ'), ('comedies', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('legendary', 'JJ'), ('chick', 'NNP'), ('morton', 'NNP'), ('and', 'CC'), ('eddie', 'NNP'), ('hayes', 'NNP'), (',', ','), ('long', 'JJ'), ('believed', 'VBD'), ('lost', 'VBN'), (',', ','), ('have', 'VBP'), ('been', 'VBN'), ('discovered', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('forgotten', 'VBN'), ('film', 'NN'), ('vault', 'NN'), ('and', 'CC'), ('tonight', 'RB'), ('they', 'PRP'), ("'ll", 'MD'), ('begin', 'VB'), ('an', 'DT'), ('unprecedented', 'JJ'), ('revival', 'NN'), ('on', 'IN'), ('cbs', 'NNP'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=12, context=[('we', 'PRP'), ('are', 'VBP'), ('americans', 'NNPS'), (':', ':'), ('we', 'PRP'), ('have', 'VBP'), ('a', 'DT'), ('unique', 'JJ'), ('responsibility', 'NN'), ('to', 'TO'), ('do', 'VB'), ('the', 'DT'), ('hard', 'JJ'), ('work', 'NN'), ('of', 'IN'), ('freedom', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=4, context=[('suddenly', 'RB'), ('his', 'PRP$'), ('voice', 'NN'), ('grew', 'VBD'), ('hard', 'JJ'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=8, context=[('and', 'CC'), ('officials', 'NNS'), ('there', 'EX'), ('have', 'VBP'), ('no', 'DT'), ('incentive', 'NN'), ('to', 'TO'), ('look', 'VB'), ('hard', 'JJ'), ('at', 'IN'), ('effectiveness', 'NN'), (';', ':'), ('drug', 'NN'), ('programs', 'NNS'), ('are', 'VBP'), ('simply', 'RB'), ('paying', 'VBG'), ('the', 'DT'), ('air', 'NNP'), ('force', 'NNP'), ('and', 'CC'), ('navy', 'NNP'), ('for', 'IN'), ('the', 'DT'), ('flying', 'VBG'), ('and', 'CC'), ('steaming', 'VBG'), ('they', 'PRP'), ('would', 'MD'), ('be', 'VB'), ('doing', 'VBG'), ('anyway', 'RB'), ('out', 'IN'), ('of', 'IN'), ('their', 'PRP$'), ('own', 'JJ'), ('budgets', 'NNS'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=3, context=[('we', 'PRP'), ('learned', 'VBD'), ('the', 'DT'), ('hard', 'JJ'), ('way', 'NN'), (',', ','), ('by', 'IN'), ('trial', 'NN'), ('and', 'CC'), ('error', 'NN'), (',', ','), ('but', 'CC'), ('we', 'PRP'), ('learned', 'VBD'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=10, context=[('so', 'IN'), ('i', 'PRP'), ('clung', 'VBD'), ('to', 'TO'), ('this', 'DT'), ('shadowy', 'JJ'), ('mardonius', 'NNP'), (',', ','), ('simultaneously', 'RB'), ('a', 'DT'), ('hard', 'JJ'), (',', ','), ('noble', 'JJ'), ('greek', 'NNP'), ('soldier', 'NN'), ('and', 'CC'), ('a', 'DT'), ('soft', 'JJ'), (',', ','), ('curling-lipped', 'NNP'), ('persian', 'NNP'), ('tyrant', 'NN'), (';', ':'), ('bearded', 'JJ'), ('and', 'CC'), ('clean-shaven', 'JJ'), (';', ':'), ('on', 'IN'), ('both', 'DT'), ('sides', 'NNS'), ('at', 'IN'), ('once', 'RB'), (',', ','), ('a', 'DT'), ('faint', 'JJ'), ('ghost-mardonius', 'NN'), ('in', 'IN'), ('the', 'DT'), ('sky', 'NN'), (';', ':'), ('a', 'DT'), ('potentiality', 'NN'), (',', ','), ('only', 'RB'), ('half-real', 'JJ'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=17, context=[('they', 'PRP'), ('played', 'VBD'), ('all', 'PDT'), ('the', 'DT'), ('songs', 'NNS'), ('from', 'IN'), ('their', 'PRP$'), ('successful', 'JJ'), ('album', 'NN'), (',', ','), ('``', '``'), ('schubert', 'NNP'), ('dip', 'VB'), (',', ','), ('"', '"'), ('with', 'IN'), ('a', 'DT'), ('harder', 'JJ'), ('edge', 'NN'), ('than', 'IN'), ('on', 'IN'), ('record', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=22, context=[('``', '``'), ('more', 'RBR'), ('importantly', 'RB'), (',', ','), ('it', 'PRP'), ('will', 'MD'), ('create', 'VB'), ('an', 'DT'), ('effort', 'NN'), ('-', ':'), ('and', 'CC'), ('performance-based', 'JJ'), ('system', 'NN'), ('which', 'WDT'), ('will', 'MD'), ('send', 'VB'), ('a', 'DT'), ('message', 'NN'), ('to', 'TO'), ('all', 'DT'), ('students', 'NNS'), ('that', 'IN'), ('hard', 'JJ'), ('work', 'NN'), ('pays', 'VBZ'), ('dividends', 'NNS'), (',', ','), ('that', 'IN'), ('learning', 'VBG'), ('is', 'VBZ'), ('important', 'JJ'), (',', ','), ('and', 'CC'), ('that', 'IN'), ('tough', 'JJ'), ('courses', 'NNS'), ('are', 'VBP'), ('the', 'DT'), ('path', 'NN'), ('to', 'TO'), ('success', 'NN'), (',', ','), ('"', '"'), ('cooperman', 'NNP'), ('said', 'VBD'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=19, context=[('the', 'DT'), ('truth', 'NN'), ('is', 'VBZ'), ('that', 'IN'), ('any', 'DT'), ('arab', 'NNP'), ('who', 'WP'), ('tries', 'VBZ'), ('to', 'TO'), ('make', 'VB'), ('a', 'DT'), ('stand', 'NN'), ('which', 'WDT'), ('is', 'VBZ'), ('somewhat', 'RB'), ('more', 'RBR'), ('moderate', 'JJ'), ('than', 'IN'), ('the', 'DT'), ('hard', 'JJ'), ('line', 'NN'), ('will', 'MD'), ('be', 'VB'), ('killed', 'VBN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=1, context=[('no', 'DT'), ('hard', 'JJ'), ('feelings', 'NNS'), ('developed', 'VBN'), ('and', 'CC'), ('within', 'IN'), ('months', 'NNS'), ('rosenberg', 'NNP'), ('followed', 'VBD'), ('cooley', 'NNP'), ('to', 'TO'), ('seafirst', 'NNP'), (',', ','), ('washington', 'NNP'), ('state', 'NN'), ("'s", 'POS'), ('largest', 'JJS'), ('bank', 'NN'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=20, context=[('the', 'DT'), ('last', 'NNP'), ('word', 'NN'), (';', ':'), ('water', 'NNP'), ('smart', 'JJ'), (';', ':'), ('with', 'IN'), ('severe', 'JJ'), ('water', 'NN'), ('rationing', 'NN'), ('hanging', 'VBG'), ('over', 'IN'), ('our', 'PRP$'), ('heads', 'NNS'), (',', ','), ('take', 'VB'), ('time', 'NN'), ('for', 'IN'), ('a', 'DT'), ('hard', 'JJ'), ('look', 'NN'), ('at', 'IN'), ('your', 'PRP$'), ('garden', 'NN'), ('to', 'TO'), ('weed', 'VB'), ('out', 'RP'), ('the', 'DT'), ('wimps', 'NNS'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=27, context=[('now', 'RB'), ('two', 'CD'), ('research', 'NN'), ('psychologists', 'NNS'), ('at', 'IN'), ('the', 'DT'), ('university', 'NNP'), ('of', 'IN'), ('california', 'NNP'), (',', ','), ('santa', 'NNP'), ('cruz', 'NNP'), (',', ','), ('who', 'WP'), ('just', 'RB'), ('happen', 'VB'), ('to', 'TO'), ('be', 'VB'), ('married', 'VBN'), ('to', 'TO'), ('each', 'DT'), ('other', 'NN'), (',', ','), ('want', 'VBP'), ('to', 'TO'), ('take', 'VB'), ('a', 'DT'), ('hard', 'JJ'), (',', ','), ('scientific', 'JJ'), ('look', 'NN'), ('at', 'IN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('more', 'RBR'), ('interesting', 'JJ'), ('aspects', 'NNS'), ('of', 'IN'), ('amore', 'RB'), ('.', '.')], senses=('HARD2',)),
#  SensevalInstance(word='hard-a', position=49, context=[('over', 'IN'), ('the', 'DT'), ('years', 'NNS'), (',', ','), ('charlie', 'NNP'), ("'s", 'POS'), ('seen', 'VBN'), ('just', 'RB'), ('about', 'IN'), ('every', 'DT'), ('way', 'NN'), ('a', 'DT'), ('human', 'JJ'), ('life', 'NN'), ('can', 'MD'), ('end', 'VB'), ('--', ':'), ('heart', 'NN'), ('attack', 'NN'), (',', ','), ('stroke', 'NN'), (',', ','), ('car', 'NN'), ('accident', 'NN'), (',', ','), ('hanging', 'VBG'), (',', ','), ('suffocation', 'NN'), (',', ','), ('crib', 'NN'), ('death', 'NN'), (',', ','), ('drowning', 'VBG'), (',', ','), ('even', 'RB'), ('a', 'DT'), ('few', 'JJ'), ('murders', 'NNS'), ('--', ':'), ('and', 'CC'), ('just', 'RB'), ('about', 'IN'), ('every', 'DT'), ('way', 'NN'), ('the', 'DT'), ('survivors', 'NNS'), ('deal', 'VBP'), ('with', 'IN'), ('that', 'DT'), ('hard', 'JJ'), ('reality', 'NN'), ('.', '.')], senses=('HARD2',)),
# ...
#  SensevalInstance(word='hard-a', position=29, context=[('goalkeeper', 'NNP'), (';', ':'), ('face', 'NNP'), ('mask', 'NN'), ('--', ':'), ('it', 'PRP'), ('has', 'VBZ'), ('evolved', 'VBN'), ('from', 'IN'), ('the', 'DT'), ('jason', 'NNP'), ('mask', 'NN'), ('you', 'PRP'), ('see', 'VBP'), ('in', 'IN'), ('horror', 'NN'), ('movies', 'NNS'), ('to', 'TO'), ('awire', 'VB'), ('cage', 'NN'), ('that', 'WDT'), ('attaches', 'VBZ'), ('to', 'TO'), ('the', 'DT'), ('helmet', 'NN'), ('or', 'CC'), ('a', 'DT'), ('high-tech', 'NN'), (',', ','), ('hard', 'JJ'), ('plastic', 'NN'), ('mask-helmet', 'JJ'), ('combination', 'NN'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=2, context=[('bumpy', 'NNP'), (',', ','), ('hard', 'JJ'), ('skinned', 'VBN'), (',', ','), ('irregularly', 'RB'), ('shaped', 'VBN'), ('squash', 'NN'), ('typifies', 'VBZ'), ('american', 'JJ'), ('fall', 'NN'), ('and', 'CC'), ('winter', 'NN'), ('harvest', 'NN'), ('food', 'NN'), ('at', 'IN'), ('its', 'PRP$'), ('best', 'JJS'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=17, context=[('true', 'JJ'), ('noir', 'FW'), ('believers', 'NNS'), ('also', 'RB'), ('can', 'MD'), ('purchase', 'VB'), ('a', 'DT'), ('``', '``'), ('new', 'JJ'), ("''", "''"), ('-', ':'), ('lrb', 'NNP'), ('-', ':'), ('first', 'JJ'), ('time', 'NN'), ('published', 'VBN'), ('in', 'IN'), ('hard', 'JJ'), ('covers', 'NNS'), ('-', ':'), ('rrb', 'NNP'), ('-', ':'), ('novel', 'NN'), ('by', 'IN'), ('dashiell', 'NNP'), ('hammett', 'NNP'), (',', ','), ('``', '``'), ('woman', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('dark', 'NNP'), (':', ':'), ('a', 'DT'), ('novel', 'NNP'), ('of', 'IN'), ('dangerous', 'NNP'), ('romance', 'NNP'), ("''", "''"), ('-', ':'), ('lrb', 'NNP'), ('-', ':'), ('knopf', 'NNP'), (',', ','), ('76', 'CD'), ('pages', 'NNS'), (',', ','), ('$', '$'), ('15', 'CD'), ('.', '.'), ('95', 'CD'), ('-', ':'), ('rrb', 'NNP'), ('-', ':'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=26, context=[('if', 'IN'), ('necessary', 'JJ'), (',', ','), ('trim', 'VB'), ('it', 'PRP'), ('by', 'IN'), ('using', 'VBG'), ('the', 'DT'), ('straightedge', 'NN'), ('and', 'CC'), ('a', 'DT'), ('fresh', 'JJ'), ('knife', 'NN'), ('blade', 'NN'), (',', ','), ('or', 'CC'), ('by', 'IN'), ('rubbing', 'VBG'), ('it', 'PRP'), ('against', 'IN'), ('fine-grit', 'JJ'), ('sandpaper', 'NN'), ('laid', 'VBD'), ('flat', 'JJ'), ('on', 'IN'), ('a', 'DT'), ('hard', 'JJ'), ('work', 'NN'), ('surface', 'NN'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=10, context=[('for', 'IN'), ('instance', 'NN'), (',', ','), ('i', 'PRP'), ('painted', 'VBD'), ('a', 'DT'), ('planted', 'VBN'), ('walkway', 'NN'), ('on', 'IN'), ('a', 'DT'), ('hard', 'JJ'), ('surface', 'NN'), ('to', 'TO'), ('save', 'VB'), ('water', 'NN'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=7, context=[('i', 'PRP'), ('don', 'VBP'), ("'t", 'VBG'), ('think', 'VBP'), ('i', 'PRP'), ('have', 'VBP'), ('a', 'DT'), ('hard', 'JJ'), ('nose', 'NN'), (',', ','), ('"', '"'), ('he', 'PRP'), ('says', 'VBZ'), (',', ','), ('stroking', 'VBG'), ('the', 'DT'), ('bridge', 'NN'), ('of', 'IN'), ('his', 'PRP$'), ('nose', 'NN'), (',', ','), ('``', '``'), ('and', 'CC'), ('i', 'PRP'), ('love', 'VBP'), ('nonsense', 'NN'), ('.', '.'), ("''", "''")], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=21, context=[('someday', 'RB'), ('you', 'PRP'), ("'ll", 'MD'), ('be', 'VB'), ('walking', 'VBG'), ('through', 'IN'), ('the', 'DT'), ('forest', 'NN'), ('in', 'IN'), ('the', 'DT'), ('dead', 'NN'), ('of', 'IN'), ('winter', 'NN'), ('and', 'CC'), ('you', 'PRP'), ("'ll", 'MD'), ('stub', 'VB'), ('your', 'PRP$'), ('boot', 'NN'), ('on', 'IN'), ('something', 'NN'), ('hard', 'JJ'), (':', ':'), ('a', 'DT'), ('frog', 'NN'), ('!', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=10, context=[('now', 'RB'), ('we', 'PRP'), ('were', 'VBD'), ('sleeping', 'VBG'), ('on', 'IN'), ('a', 'DT'), ('bed', 'NN'), ('that', 'WDT'), ('was', 'VBD'), ('so', 'RB'), ('hard', 'JJ'), ('and', 'CC'), ('so', 'RB'), ('flat', 'JJ'), ('that', 'IN'), ('i', 'PRP'), ('felt', 'VBD'), ('as', 'IN'), ('if', 'IN'), ('staked', 'VBN'), ('out', 'RP'), ('for', 'IN'), ('birds', 'NNS'), ('of', 'IN'), ('prey', 'NN'), ('in', 'IN'), ('the', 'DT'), ('desert', 'NN'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=10, context=[('just', 'RB'), ('before', 'IN'), ('serving', 'VBG'), (',', ','), ('crisp', 'JJ'), ('tortillas', 'NNS'), ('as', 'IN'), ('above', 'IN'), ('but', 'CC'), ('leave', 'NN'), ('hard', 'JJ'), ('and', 'CC'), ('flat', 'JJ'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=17, context=[('c', 'NN'), ('.', '.'), ('edward', 'NNP'), ('acker', 'JJ'), (',', ','), ('pan', 'NNP'), ('am', 'NNP'), ("'s", 'POS'), ('chairman', 'NN'), (',', ','), ('remains', 'VBZ'), ('caught', 'VBN'), ('between', 'IN'), ('a', 'DT'), ('rock', 'NN'), ('and', 'CC'), ('a', 'DT'), ('hard', 'JJ'), ('place', 'NN'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=12, context=[('before', 'IN'), ('mr', 'NNP'), ('.', '.'), ('hoffman', 'NNP'), ('entered', 'VBD'), ('the', 'DT'), ('business', 'NN'), ('a', 'DT'), ('decade', 'NN'), ('ago', 'RB'), (',', ','), ('a', 'DT'), ('hard', 'JJ'), ('cover', 'NN'), ('fiction', 'NN'), ('best', 'JJS'), ('seller', 'NN'), ('sold', 'VBN'), ('150', 'CD'), (',', ','), ('000', 'CD'), ('copies', 'NNS'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=11, context=[('replacement', 'NN'), ('leads', 'VBZ'), ('and', 'CC'), ('scribes', 'NNS'), ('for', 'IN'), ('marking', 'VBG'), ('metal', 'NN'), (',', ','), ('glass', 'NN'), ('and', 'CC'), ('other', 'JJ'), ('hard', 'JJ'), ('materials', 'NNS'), ('are', 'VBP'), ('stored', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('tape', 'NN'), ('rule', 'NN'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=5, context=[('if', 'IN'), ('you', 'PRP'), ("'re", 'VBP'), ('driving', 'VBG'), ('a', 'DT'), ('hard', 'JJ'), ('topped', 'VBD'), ('car', 'NN'), (',', ','), ('stay', 'VB'), ('with', 'IN'), ('it', 'PRP'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=7, context=[('harvest', 'NNP'), ('all', 'PDT'), ('the', 'DT'), ('fruit', 'NN'), ('before', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('hard', 'JJ'), ('freeze', 'NN'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=46, context=[('never', 'RB'), ('let', 'VB'), ('the', 'DT'), ('soil', 'NN'), ('dry', 'JJ'), ('out', 'IN'), (',', ','), ('watch', 'NN'), ('for', 'IN'), ('whiteflies', 'NNS'), ('and', 'CC'), ('powdery', 'JJ'), ('mildew', 'NN'), (',', ','), ('feed', 'NN'), ('generously', 'RB'), ('with', 'IN'), ('a', 'DT'), ('10', 'CD'), ('percent', 'NN'), ('nitrogen', 'NN'), ('fertilizer', 'NN'), ('every', 'DT'), ('other', 'JJ'), ('week', 'NN'), (',', ','), ('prop', 'VB'), ('the', 'DT'), ('ripening', 'VBG'), ('pumpkins', 'NNS'), ('up', 'IN'), ('on', 'IN'), ('boards', 'NNS'), ('to', 'TO'), ('prevent', 'VB'), ('rotting', 'VBG'), ('the', 'DT'), ('bottom', 'NN'), ('and', 'CC'), ('harvest', 'NN'), ('them', 'PRP'), ('when', 'WRB'), ('the', 'DT'), ('rind', 'NN'), ('starts', 'VBZ'), ('getting', 'VBG'), ('hard', 'JJ'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=4, context=[('these', 'DT'), ('cookies', 'NNS'), ('start', 'VBP'), ('out', 'IN'), ('hard', 'JJ'), ('and', 'CC'), ('soften', 'VB'), ('as', 'IN'), ('they', 'PRP'), ('mature', 'JJ'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=23, context=[('becker', 'NNP'), ('matched', 'VBD'), ('lendl', 'NNP'), ("'s", 'POS'), ('nine', 'CD'), ('aces', 'NNS'), (',', ','), ('but', 'CC'), ('won', 'VBD'), ('this', 'DT'), ('match', 'NN'), ('with', 'IN'), ('his', 'PRP$'), ('more', 'RBR'), ('dynamic', 'JJ'), ('play', 'NN'), ('at', 'IN'), ('the', 'DT'), ('net', 'NN'), (',', ','), ('frolicking', 'VBG'), ('on', 'IN'), ('the', 'DT'), ('hard', 'JJ'), ('court', 'NN'), ('as', 'IN'), ('if', 'IN'), ('it', 'PRP'), ('were', 'VBD'), ('wimbledon', 'NNP'), ("'s", 'POS'), ('grass', 'NN'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=8, context=[('it', 'PRP'), ("'s", 'VBZ'), ('all', 'DT'), ('done', 'VBN'), ('with', 'IN'), ('bean', 'NN'), ('curd', 'NN'), ('--', ':'), ('hard', 'JJ'), ('and', 'CC'), ('soft', 'JJ'), (',', ','), ('fried', 'JJ'), ('and', 'CC'), ('steamed', 'VBN'), ('and', 'CC'), ('broiled', 'VBN'), ('and', 'CC'), ('who', 'WP'), ('knows', 'VBZ'), ('what', 'WP'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=7, context=[('you', 'PRP'), ('just', 'RB'), ('have', 'VBP'), ('to', 'TO'), ('work', 'VB'), ('a', 'DT'), ('little', 'JJ'), ('harder', 'JJ'), ('to', 'TO'), ('keep', 'VB'), ('the', 'DT'), ('relationship', 'NN'), ('going', 'VBG'), ('.', '.'), ("''", "''")], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=15, context=[('they', 'PRP'), ('found', 'VBD'), ('that', 'IN'), ('a', 'DT'), ('way', 'NN'), ('to', 'TO'), ('get', 'VB'), ('a', 'DT'), ('pretty', 'JJ'), ('tomato', 'NN'), ('to', 'TO'), ('market', 'VB'), ('was', 'VBD'), ('to', 'TO'), ('pick', 'VB'), ('hard', 'JJ'), (',', ','), ('unripe', 'JJ'), ('ones', 'NNS'), ('and', 'CC'), ('gas', 'NN'), ('them', 'PRP'), ('red', 'JJ'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=12, context=[('mclaughlin', 'NNP'), ('recommended', 'VBD'), ('during', 'IN'), ('the', 'DT'), ('class', 'NN'), ('that', 'IN'), ('bikers', 'NNS'), ('riding', 'VBG'), ('down', 'RP'), ('a', 'DT'), ('steep', 'NN'), (',', ','), ('hard', 'JJ'), ('packed', 'VBN'), ('dirt', 'NN'), ('hill', 'NN'), ('do', 'VBP'), ('most', 'RBS'), ('of', 'IN'), ('the', 'DT'), ('braking', 'NN'), ('with', 'IN'), ('the', 'DT'), ('back', 'JJ'), ('brake', 'NN'), ('and', 'CC'), ('use', 'VB'), ('the', 'DT'), ('front', 'NN'), ('brake', 'NN'), ('sparingly', 'RB'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=5, context=[('the', 'DT'), ('hyper', 'NNP'), ('pad', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('hard', 'JJ'), ('surface', 'NN'), ('mousepad', 'NN'), ('that', 'WDT'), ('contains', 'VBZ'), ('the', 'DT'), ('same', 'JJ'), ('heat-sensitive', 'JJ'), ('liquid', 'JJ'), ('crystals', 'NNS'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=29, context=[('stich', 'NNP'), (',', ','), ('stretched', 'VBD'), ('to', 'TO'), ('five', 'CD'), ('sets', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('third', 'JJ'), ('round', 'NN'), ('by', 'IN'), ('malivai', 'NNP'), ('washington', 'NNP'), (',', ','), ('looked', 'VBD'), ('so', 'RB'), ('comfortable', 'JJ'), ('on', 'IN'), ('wimbledon', 'NNP'), ("'s", 'POS'), ('grass', 'NN'), ('but', 'CC'), ('has', 'VBZ'), ('n', 'NN'), ("'t", 'NN'), ('adjusted', 'VBN'), ('to', 'TO'), ('the', 'DT'), ('medium-fast', 'JJ'), ('hard', 'JJ'), ('courts', 'NNS'), ('at', 'IN'), ('the', 'DT'), ('national', 'NNP'), ('tennis', 'NNP'), ('center', 'NNP'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=20, context=[('if', 'IN'), ('someone', 'NN'), ('is', 'VBZ'), ('moving', 'VBG'), ('from', 'IN'), ('a', 'DT'), ('larger', 'JJR'), ('apartment', 'NN'), ('to', 'TO'), ('a', 'DT'), ('smaller', 'JJR'), ('one', 'CD'), (',', ','), ('mr', 'NNP'), ('.', '.'), ('thometz', 'NNP'), ('may', 'MD'), ('also', 'RB'), ('weed', 'VB'), ('out', 'IN'), ('hard', 'JJ'), ('cover', 'NN'), ('classics', 'NNS'), ('that', 'WDT'), ('are', 'VBP'), ('readily', 'RB'), ('available', 'JJ'), ('in', 'IN'), ('paperback', 'NN'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=7, context=[('instead', 'RB'), (',', ','), ('tie', 'NN'), ('a', 'DT'), ('cushion', 'NN'), ('on', 'IN'), ('a', 'DT'), ('hard', 'JJ'), ('headboard', 'NN'), ('for', 'IN'), ('comfortable', 'JJ'), ('sitting', 'NN'), ('in', 'IN'), ('bed', 'NN'), ('.', '.'), ("''", "''")], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=23, context=[('``', '``'), ('no', 'DT'), ('way', 'NN'), ('i', 'PRP'), ("'m", 'VBP'), ('going', 'VBG'), ('to', 'TO'), ('miss', 'VB'), ('that', 'IN'), (',', ','), ('even', 'RB'), ('kicking', 'VBG'), ('a', 'DT'), ('ball', 'NN'), ('that', 'WDT'), ('feels', 'VBZ'), ('like', 'IN'), ('a', 'DT'), ('brick', 'NN'), ('on', 'IN'), ('a', 'DT'), ('rock', 'NN'), ('-', ':'), ('hard', 'JJ'), ('field', 'NN'), ('against', 'IN'), ('the', 'DT'), ('wind', 'NN'), ('.', '.'), ("''", "''")], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=59, context=[('although', 'IN'), ('there', 'EX'), ('is', 'VBZ'), ('no', 'DT'), ('question', 'NN'), ('but', 'CC'), ('that', 'IN'), ('the', 'DT'), ('process', 'NN'), ('of', 'IN'), ('washing', 'VBG'), ('fabrics', 'NNS'), ('involves', 'VBZ'), ('a', 'DT'), ('number', 'NN'), ('of', 'IN'), ('phenomena', 'NNS'), ('which', 'WDT'), ('are', 'VBP'), ('related', 'VBN'), ('together', 'RB'), ('in', 'IN'), ('an', 'DT'), ('extremely', 'RB'), ('complicated', 'VBN'), ('way', 'NN'), ('and', 'CC'), ('that', 'IN'), ('these', 'DT'), ('phenomena', 'NNS'), ('and', 'CC'), ('their', 'PRP$'), ('interrelations', 'NNS'), ('are', 'VBP'), ('not', 'RB'), ('well', 'RB'), ('understood', 'VBN'), ('at', 'IN'), ('the', 'DT'), ('present', 'NN'), (',', ','), ('this', 'DT'), ('section', 'NN'), ('attempts', 'NNS'), ('to', 'TO'), ('present', 'VB'), ('briefly', 'NN'), ('an', 'DT'), ('up-to-date', 'JJ'), ('picture', 'NN'), ('of', 'IN'), ('the', 'DT'), ('physical', 'JJ'), ('chemistry', 'NN'), ('of', 'IN'), ('washing', 'VBG'), ('either', 'DT'), ('fabrics', 'NNS'), ('or', 'CC'), ('hard', 'JJ'), ('surfaces', 'NNS'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=6, context=[('the', 'DT'), ('so-called', 'JJ'), ('vegetable', 'NN'), ('ivory', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('hard', 'JJ'), ('endosperm', 'NN'), ('of', 'IN'), ('the', 'DT'), ('egg-sized', 'JJ'), ('seed', 'NN'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=14, context=[('mr', 'NNP'), ('.', '.'), ('condello', 'NNP'), ('once', 'RB'), ('said', 'VBD'), ('the', 'DT'), ('worst', 'JJS'), ('thing', 'NN'), ('about', 'IN'), ('the', 'DT'), ('state', 'NN'), ('capitol', 'NNP'), ('was', 'VBD'), ('its', 'PRP$'), ('hard', 'JJ'), ('floors', 'NNS'), (',', ','), ('the', 'DT'), ('tiled', 'JJ'), (',', ','), ('marble', 'NN'), ('corridors', 'NNS'), ('and', 'CC'), ('stone', 'NN'), ('stairs', 'NNS'), ('that', 'IN'), ('he', 'PRP'), ('trampled', 'VBD'), ('over', 'IN'), ('each', 'DT'), ('working', 'VBG'), ('day', 'NN'), ('for', 'IN'), ('a', 'DT'), ('decade', 'NN'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=2, context=[('remove', 'VB'), ('the', 'DT'), ('hard', 'JJ'), ('outer', 'JJ'), ('shell', 'NN'), ('of', 'IN'), ('the', 'DT'), ('acorn', 'RB'), ('with', 'IN'), ('a', 'DT'), ('nut', 'NN'), ('cracker', 'NN'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=1, context=[('a', 'DT'), ('harder', 'JJ'), ('skin', 'NN'), ('will', 'MD'), ('allow', 'VB'), ('the', 'DT'), ('fruit', 'NN'), ('to', 'TO'), ('store', 'VB'), ('better', 'JJR'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=19, context=[('since', 'IN'), ('the', 'DT'), ('1950s', 'CD'), (',', ','), ('it', 'PRP'), ('has', 'VBZ'), ('cost', 'NN'), ('twice', 'RB'), ('the', 'DT'), ('national', 'JJ'), ('average', 'JJ'), ('to', 'TO'), ('build', 'VB'), ('a', 'DT'), ('mile', 'NN'), ('of', 'IN'), ('highway', 'NN'), ('through', 'IN'), ('this', 'DT'), ('hard', 'JJ'), ('scrabble', 'JJ'), ('state', 'NN'), ('.', '.')], senses=('HARD3',)),
#  SensevalInstance(word='hard-a', position=4, context=[('one', 'CD'), ('example', 'NN'), (':', ':'), ('the', 'DT'), ('hard', 'JJ'), ('stick', 'NN'), ('of', 'IN'), ('the', 'DT'), ('timpanist', 'NN'), ('virtually', 'RB'), ('turns', 'VBZ'), ('the', 'DT'), ('opening', 'NN'), ('minute', 'NN'), ('into', 'IN'), ('a', 'DT'), ('kettle-drum', 'JJ'), ('concerto', 'NN'), ('.', '.')], senses=('HARD3',))]

# %% [markdown]
#  So the senseval corpus is a collection of information about a set of tagged sentences, where each entry or instance consists of 4 attributes:
#
# * word specifies the target word together with its syntactic category (e.g., hard-a means that the word is hard and its category is 'adjective');
# * position gives its position within the sentence (ignoring punctuation);
# * context represents the sentence as a list of pairs, each pair being a word or punctuation mark and its tag; and finally
# * senses is a tuple, each item in the tuple being a sense for that target word. In the subset of the corpus we are working with, this tuple consists of only one argument. But there are a few examples elsewhere in the corpus where there is more than one, representing the fact that the annotator couldn't decide which sense to assign to the word. For simplicity, our classifiers are going to ignore any non-first arguments to the attribute senses.

# %% [markdown]
# ## Exploring different WSD classifiers
# You're now going to compare the performance of different classifiers that perform word sense disambiguation. You do this by calling the function `WSDClassifer` This function must have at least the following arguments specified by you:
#
# 1. A trainer; e.g., `NaiveBayesClassifier.train` (if you want you could also try `MaxentClassifier.train`, but this takes longer to train).
# 2. The target word that the classifier is going to learn to disambiguate: i.e., 'hard.pos', 'line.pos', 'interest.pos' or 'serve.pos'.
# 3. A feature set. The code allows you to use two kinds of feature sets:
#
# **word_features**
#
# This feature set is based on the set **S&nbsp;** of the **n&nbsp;** most frequent words that occur in the same sentence as the target word **w&nbsp;** across the entire training corpus (as you'll see later, you can specify the value of **n&nbsp;**, but if you don't specify it then it defaults to 300). For each occurrence of **w,** `word_features` represents its context as the subset of those words from **S&nbsp;** that occur in the **w&nbsp;**'s sentence. By default, the closed-class words that are specified in `STOPWORDS` are excluded from the set **S&nbsp;** of most frequent words. But as we'll see later, you can also include closed-class words in **S&nbsp;**, or re-define closed-class words in any way you like! If you want to know what closed-class words are excluded by default, just look at the code above.
#
# **context_features**
#
# This feature set represents the context of a word **w&nbsp;** as the sequence of **m&nbsp;** pairs `(word,tag)` that occur before **w&nbsp;** and the sequence of **m&nbsp;** pairs `(word, tag)` that occur after **w&nbsp;**. As we'll see shortly, you can specify the value of **m&nbsp;** (e.g., `m=1` means the context consists of just the immediately prior and immediately subsequent word-tag pairs); otherwise, **m&nbsp;** defaults to 3.
#
#
# ### first WSD classifier
# Try the following:

# %%
WSDClasifier(NaiveBayesClassifier.train, 'hard.pos', word_features)
# Out:
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8328

# %% [markdown]
# In other words, the adjective hard is tagged with 3 senses in the corpus (HARD1, HARD2 and HARD3), and the Naive Bayes Classifier using the feature set based on the 300 most frequent context words yields an accuracy of 0.8362.
#
# ### Now it's your turn:
#
# Use `WSDClassifier` to train a classifier that disambiguates hard using `context_features`. Build classifiers for *line* and *serve* as well, using the word features and then the context features.
#
# * What's more accurate for disambiguating 'hard.pos', `context_features` or `word_features`?
# * Does the same hold true for 'line.pos' and 'serve.pos'. Why do you think that might be?
# * Why is it not fair to compare the accuracy of the classifiers across different target words?
#
#
# ### Baseline models
# Just how good is the accuracy of these WSD classifiers? To find out, we need a baseline. There are two we consider here:
#
# 1. A model which assigns a sense at random.
# 2. A model which always assigns the most frequent sense.
#
# ### Now it's your turn:
#
# * What is the accuracy of the random baseline model for 'hard.pos'?
# * To compute the accuracy of the frequency baseline model for 'hard.pos', we need to find out the Frequency Distribution of the three senses in the corpus:

# %%
hard_sense_fd = nltk.FreqDist([i.senses[0] for i in senseval.instances('hard.pos')])
print(hard_sense_fd.most_common())

# Most common word: 'HARD1'
frequency_hard_sense_baseline = hard_sense_fd.freq('HARD1')
print('Baseline accuracy: {}'.format(frequency_hard_sense_baseline))
# Out:
# [('HARD1', 3455), ('HARD2', 502), ('HARD3', 376)]
# Baseline accuracy: 0.797369028386799

# %% [markdown]
#  In other words, the frequency baseline has an accuracy of approx. 0.797. What is the most frequent sense for 'hard.pos'? And is the frequency baseline a better model than the random model?
# * Now compute the accuracy of the frequency baseline for other target words; e.g. 'line.pos'.

# %%
print(instance2senses('line.pos'))
# Out:
# ['formation', 'division', 'product', 'text', 'phone', 'cord']

# %%
line_sense_fd = nltk.FreqDist([i.senses[0] for i in senseval.instances('line.pos')])
print(line_sense_fd.most_common())

# Most common word: 'product'
frequency_line_sense_baseline = line_sense_fd.freq('product')
print('Baseline accuracy: {}'.format(frequency_line_sense_baseline))
# Out:
# [('product', 2217), ('phone', 429), ('text', 404), ('division', 374), ('cord', 373), ('formation', 349)]
# Baseline accuracy: 0.5347322720694645

# %% [markdown]
# ## Rich features vs. sparse data
# In this part of the tutorial, we are going to vary the feature sets and compare the results. As well as being able to choose between `context_features` vs. `word_features`, you can also vary the following:
#
# ### context_features
#
# You can vary the number of word-tag pairs before and after the target word that you include in the feature vector. You do this by specifying the argument `distance` to the function `WSDClassifier`. For instance, the following creates a classifier that uses 2 words to the left and right of the target word:
#
# ```python
# WSDClassifier(trainer=NaiveBayesClassifier.train,
#               words='hard.pos',
#               features=context_features,
#               distance=2)
# ```
#
# What about distance 1?
# ### word_features
# You can vary the closed-class words that are excluded from the set of most frequent words, and you can vary the size of the set of most frequent words. For instance, the following results in a model which uses the 100 most frequent words including closed-class words:
#
# ```python
# WSDClassifier(trainer=NaiveBayesClassifier.train,
#               words='hard.pos',
#               features=word_features,
#               stopwords=[],
#               number=100)
# ```
# ### Now it's your turn:
# Build several WSD models for 'hard.pos', including at least the following: for the `word_features` version, vary `number` between 100, 200 and 300, and vary the `stopwords` between `[]` (i.e., the empty list) and `STOPWORDS`; for the `context_features` version, vary the `distance` between 1, 2 and 3, and vary the `stopwords` between `[]` and `STOPWORDS`.

# %%
"""
You can vary the closed-class words that are excluded from the set of most frequent words, 
and you can vary the size of the set of most frequent words. 
For instance, the following results in a model which uses the 100,200 and 300 most frequent words 
including closed-class words.
"""
for n in [100, 200, 300, 400]: # vary number between 100, 200 and 300
    # vary stopwords between [] and STOPWORDS
    for stopwords in [[], STOPWORDS]:
        stop = 'stopwords' if stopwords else 'no stopwords'
        print('Word features with number: {} and {}'.format(n, stop))
        WSDClasifier(trainer=NaiveBayesClassifier.train,
                     word='hard.pos',
                     features=word_features,
                     stopwords=stopwords,
                     number=n)
# Out:
# Word features with number: 100 and no stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8351
# Word features with number: 100 and stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8351
# Word features with number: 200 and no stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8374
# Word features with number: 200 and stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8374
# Word features with number: 300 and no stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8328
# Word features with number: 300 and stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8328
# Word features with number: 400 and no stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8304
# Word features with number: 400 and stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8304

# %%
"""
You can vary the number of word-tag pairs before and after the target word that you include in the feature vector. 
You do this by specifying the argument distance to the function WSDClassifier. 
For instance, the following creates a classifier that uses 1, 2 and 3 words to the left and right 
of the target word.
"""

for n in [1, 2, 3]:
    for stopwords in [[], STOPWORDS]:
        stop = 'stopwords' if stopwords else 'no stopwords'
        print('Context features with distance: {} and {}'.format(n, stop))
        WSDClasifier(trainer=NaiveBayesClassifier.train,
                    word='hard.pos',
                    features=context_features,
                    stopwords=stopwords,
                    distance=n)
# Out:
# Context features with distance: 1 and no stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8927
# Context features with distance: 1 and stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8927
# Context features with distance: 2 and no stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8731
# Context features with distance: 2 and stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8731
# Context features with distance: 3 and no stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8697
# Context features with distance: 3 and stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8697

# %% [markdown]
# Why does changing `number` have an inconsistent impact on the word model?
#   * This suggests that the data is too sparse for changes in vocabulary size to have a consistent impact.
#
# Why does making the context window before and after the target word to a number smaller than 3 improve the model?
#   * Sparse data, again
#
# Why does including closed-class words in word model improve overall performance?
#
#   * Including closed class words improves performance.  One can see from
# the distinct list of closed class words that are constructed for each
# sense of "hard" that the distributions of closed class wrt word sense
# are quite distinct and therefore informative.  Furthermore, by
# including closed class words within the context window one *excludes*
# open class words that may be, say, 5 or 6 words away from the target
# word and are hence less informative clues for the target word sense.
#
# To see if the data really is too sparse for consistent results, try a different seed for the random number generator, by
# editting line 211 in the definition of `WSDClassifier` to use the seed value from the comment instead of the one it's been using.  Then try again and see how, if at all, the trend as number increases is different.

# %%
for n in [100, 200, 300, 400]:
    for stopwords in [[], STOPWORDS]:
        stop = 'stopwords' if stopwords else 'no stopwords'
        print('Word features with number: {} and {}'.format(n, stop))
        WSDClasifier(trainer=NaiveBayesClassifier.train,
                     word='hard.pos',
                     features=word_features,
                     stopwords=stopwords,
                     number=n)
# Out:
# Word features with number: 100 and no stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8351
# Word features with number: 100 and stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8351
# Word features with number: 200 and no stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8374
# Word features with number: 200 and stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8374
# Word features with number: 300 and no stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8328
# Word features with number: 300 and stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8328
# Word features with number: 400 and no stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8304
# Word features with number: 400 and stopwords
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8304

# %% [markdown]
# It seems slightly odd that the word features for 'hard.pos' include _harder_ and _hardest_. Try using a stopwords list which adds them to STOPWORDS: is the effect what you expected? Can you explain it?

# %%
WSDClasifier(trainer=NaiveBayesClassifier.train,
             word='hard.pos',
             features=word_features,
             number=300,
             stopwords=STOPWORDS)

WSDClasifier(trainer=NaiveBayesClassifier.train,
             word='hard.pos',
             features=word_features,
             number=300,
             stopwords=STOPWORDS.union(['harder', 'hardest']))
# Out:
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8328
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8328

# %% [markdown]
# The accuracy goes down. This might be expected if a particular word sense would be more likely to appear together with harder and hardest. This means that removing the two words would remove relevant information which would be replaced by some very infrequent words.

# %% [markdown]
# ## Error analysis
# The function `WSDClassifier` allows you to explore the errors of the model it creates:
#
# ### Confusion Matrix
#
# You can output a confusion matrix as follows:

# %%
WSDClasifier(trainer=NaiveBayesClassifier.train,
             word='hard.pos',
             features=context_features,
             distance=3,
             confusion_matrix=True)
# Out:
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8697
#       |   H   H   H |
#       |   A   A   A |
#       |   R   R   R |
#       |   D   D   D |
#       |   1   2   3 |
# ------+-------------+
# HARD1 |<625> 43  22 |
# HARD2 |  12 <79> 13 |
# HARD3 |  10  13 <50>|
# ------+-------------+
# (row = reference; col = test)

# %% [markdown]
# Note that the rows in the matrix are the gold labels, and the columns are the estimated labels. Recall that the diagonal line represents the number of items that the model gets right.
# ### Errors
#
# You can also output each error from the test data into a file `errors.txt`. For example:

# %%
WSDClasifier(trainer=NaiveBayesClassifier.train,
             word='hard.pos',
             features=context_features,
             distance=2,
             confusion_matrix=True,
             log=True)
# Out:
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8731
# Writing errors to errors.txt
#       |   H   H   H |
#       |   A   A   A |
#       |   R   R   R |
#       |   D   D   D |
#       |   1   2   3 |
# ------+-------------+
# HARD1 |<632> 35  23 |
# HARD2 |  14 <77> 13 |
# HARD3 |  11  14 <48>|
# ------+-------------+
# (row = reference; col = test)

# %% [markdown]
# Use your favourite editor to look at `errors.txt`.
# You will find it in the same directory as this notebook.

# %% [markdown]
# In `errors.txt`, the example number on the first line of each entry is the (list) index of the error in the test_data.
#
# ### Now it's your turn:
#
# 1. Choose your best performing model from your earlier trials, and train it again, but add the arguments `confusion_matrix=True` and `log=True`.
# 2. Using the confusion matrix, identify which sense is the hardest one for the model to estimate.
# 3. Look in `errors.txt` for examples where that hardest word sense is the correct label. Do you see any patterns or systematic errors? If so, can you think of a way to adapt the feature vector so as to improve the model?

# %%
WSDClasifier(trainer=NaiveBayesClassifier.train,
            word='hard.pos',
            features=context_features,
            distance=2,
            confusion_matrix=True,
            log=True)
# Out:
#  Senses: HARD3 HARD1 HARD2
# Training classifier...
# Testing classifier...
# Accuracy: 0.8731
# Writing errors to errors.txt
#       |   H   H   H |
#       |   A   A   A |
#       |   R   R   R |
#       |   D   D   D |
#       |   1   2   3 |
# ------+-------------+
# HARD1 |<632> 35  23 |
# HARD2 |  14 <77> 13 |
# HARD3 |  11  14 <48>|
# ------+-------------+
# (row = reference; col = test)

# %% [markdown]
# HARD3 is the most difficult sense for the classifier.
#
# The most obvious pattern is that HARD1 is extremely dominant in the number of examples. This can be seen in the classification results as the majority of error comes from HARD2 and HARD3 being misclassified as HARD1.
#
# It should be noted that the classifier used only looks at words at a distance of 1. This isn't very much context.
#
# Due to data sparsity I imagine that a lot of error simply comes from the fact that a particular context may not have been seen before. For example, <i>HARD shoulders</i> and <i>HARD soled shoes</i> seem like obvious examples of HARD3 but they have been classed as HARD1. Most likely these things were simply not found in the dataset.
#
# One thing that seems to happen quite a few times is that the HARD ends up next to an adverb or a different adjective, such as <i>slightly HARDER</i> which could definitely appear next to any sense of the word. What might be useful is to always include information about the POS context in which the word appears or parsing information. HARD3 will generally attach to nouns, as in <i>hard seats</i> or <i>hard hats</i>, while HARD1 has more of a spread.
